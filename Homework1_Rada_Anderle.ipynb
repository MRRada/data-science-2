# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pickle
from tqdm.notebook import tqdm
from pathlib import Path
import xgboost as xgb

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# %%
data = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_train.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')
data_test = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_train.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')

# %%
# set width of Jupyter notebook
from IPython.core.display import HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

# set some visual properties of displaying pandas DataFrame
pd.options.display.max_columns=200
pd.options.display.max_rows=200
# Out:
# <style>.container { width:70% !important; }</style>

# %%
data
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0
# ...                            ...             ...
# INN16851                       2.0             0.0
# INN06266                       NaN             1.0
# INN11285                       1.0             0.0
# INN00861                       0.0             1.0
# INN15796                       NaN             0.0
#
# [32647 rows x 18 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32647 entries, INN10204 to INN15796
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          28231 non-null  float64
#  1   no_of_children                        5043 non-null   float64
#  2   no_of_weekend_nights                  7729 non-null   float64
#  3   no_of_week_nights                     24287 non-null  float64
#  4   type_of_meal_plan                     16544 non-null  object
#  5   required_car_parking_space            17863 non-null  float64
#  6   room_type_reserved                    11360 non-null  object
#  7   lead_time                             6935 non-null   float64
#  8   arrival_year                          29654 non-null  float64
#  9   arrival_month                         31740 non-null  float64
#  10  arrival_date                          5457 non-null   float64
#  11  market_segment_type                   18526 non-null  object
#  12  repeated_guest                        7669 non-null   float64
#  13  no_of_previous_cancellations          32578 non-null  float64
#  14  no_of_previous_bookings_not_canceled  18026 non-null  float64
#  15  avg_price_per_room                    9058 non-null   float64
#  16  no_of_special_requests                25197 non-null  float64
#  17  booking_status                        32295 non-null  float64
# dtypes: float64(15), object(3)
# memory usage: 4.7+ MB

# %%
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18

# %%
data.rename(columns = {'booking_status':'TARGET'}, inplace = True) 
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0

# %%
col_target = "TARGET"
col_month = "arrival_month"

# %%
# define list of predictors
cols_pred = list(data.columns[0:-1])

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# required_car_parking_space              float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# repeated_guest                          float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan      object
# room_type_reserved     object
# market_segment_type    object
# dtype: object

# %%
len(cols_pred)
# Out:
# 17

# %%
data.TARGET.value_counts(dropna=False)
# Out:
# TARGET
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %%
data = data.dropna(subset=["TARGET"])

# %%
data.drop(data.loc[:,list((100*(data.isnull().sum()/len(data.index))>98))].columns)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0
# ...                            ...     ...
# INN16851                       2.0     0.0
# INN06266                       NaN     1.0
# INN11285                       1.0     0.0
# INN00861                       0.0     1.0
# INN15796                       NaN     0.0
#
# [32295 rows x 18 columns]

# %%
data['sample'] = 'default'

# use train_test_split to split the intime into train and rest (don't forget seed)
data_train, data_rest = train_test_split(data, test_size=0.4, random_state = 12)
data.loc[data_train.index, 'sample'] = 'train'
# use train_test_split to split the rest into valid and test (don't forget seed)
data_valid, data_test = train_test_split(data_rest, test_size=0.5, random_state = 12)
data.loc[data_valid.index, 'sample'] = 'valid'
data.loc[data_test.index, 'sample'] = 'test'
# Out:
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\48653020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sample'] = 'default'

# %%
def default_rate_in_time_per_sample(dt, col_target, col_month, col_sample):
    # group by over month and sample
    dt_grp = dt.groupby([col_month, col_sample]).agg(
        def_rt = (col_target, 'mean')
    ).reset_index()
    
    # pivot sample values to columns
    dt_grp_pivot = dt_grp.pivot(index = col_month, columns = col_sample, values = 'def_rt')

    # plot default rate in time
    lines = plt.plot(range(len(dt_grp_pivot)), dt_grp_pivot, marker = 'o')
    plt.xticks(range(len(dt_grp_pivot)), dt_grp_pivot.index, rotation = 90)
    # set legend
    plt.legend(iter(lines), tuple(dt_grp_pivot.columns), loc='best', bbox_to_anchor=(1.05, 1))
    
    plt.ylim([0, 1])
    plt.ylabel('default rate', loc='top')
    plt.xlabel('month', loc='right')
    
    ax = plt.gca()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('gray')
    ax.spines['bottom'].set_color('gray')
    ax.tick_params(axis='y', colors='gray')
    ax.tick_params(axis='x', colors='gray') 
    
    plt.show()

# %%
default_rate_in_time_per_sample(data, col_target, col_month, 'sample')

# %%
train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid') 
test_mask = (data['sample'] == 'test')

# %%
# find columns with infinity values
cols_with_inf = []
for col in cols_pred_num:
    if np.any(np.isinf(data[col])):
        cols_with_inf.append(col)
        print(f'Column {col} includes infinity values.')

# find columns with negative infinity values
cols_with_neginf = []
for col in cols_pred_num:
    if np.any(np.isneginf(data[col])):
        cols_with_neginf.append(col)
        print(f'Column {col} includes negative infinity values.')

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_dr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_dr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_dr'] + alpha * total_dr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
# replace infinity values
for col in cols_with_inf:
    data[col] = data[col].replace(np.inf, 9999999)

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_dr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_dr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_dr'] + alpha * total_dr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
total_dr = np.mean(data[train_mask][col_target])

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )

        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_dr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\2366410008.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['MTE_' + pred] = data[pred].map(new_vals)
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\2366410008.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['MTE_' + pred] = data[pred].map(new_vals)
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\2366410008.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['MTE_' + pred] = data[pred].map(new_vals)

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type']

# %%
data.required_car_parking_space.value_counts(dropna=False)
# Out:
# required_car_parking_space
# 0.0    17077
# NaN    14621
# 1.0      597
# Name: count, dtype: int64

# %%
data.repeated_guest.value_counts(dropna=False)
# Out:
# repeated_guest
# NaN    24715
# 0.0     7383
# 1.0      197
# Name: count, dtype: int64

# %%
# set best parameters to be used in XGBoost
params = {    
    'max_depth': 4,
    
    'objective': 'binary:logistic',
    'eval_metric': ['auc'],
}

evals_result = {}
booster = xgb.train(
    params = params,
    dtrain = xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]),
    num_boost_round = 1000,
    evals = (
        (xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]), 'train'),
        (xgb.DMatrix(data[test_mask][cols_pred], data[test_mask][col_target]), 'test'),
        (xgb.DMatrix(data[valid_mask][cols_pred], data[valid_mask][col_target]), 'valid'),        
    ),
    evals_result = evals_result,
    early_stopping_rounds = 10
)
# Out:
# [0]	train-auc:0.70896	test-auc:0.71244	valid-auc:0.70086
# [1]	train-auc:0.74298	test-auc:0.74382	valid-auc:0.73440
# [2]	train-auc:0.75825	test-auc:0.75907	valid-auc:0.75413
# [3]	train-auc:0.76795	test-auc:0.77046	valid-auc:0.76318
# [4]	train-auc:0.77516	test-auc:0.77692	valid-auc:0.76882
# [5]	train-auc:0.78349	test-auc:0.78528	valid-auc:0.77789
# [6]	train-auc:0.78574	test-auc:0.78728	valid-auc:0.77990
# [7]	train-auc:0.78985	test-auc:0.79130	valid-auc:0.78316
# [8]	train-auc:0.79269	test-auc:0.79336	valid-auc:0.78575
# [9]	train-auc:0.79447	test-auc:0.79498	valid-auc:0.78778
# [10]	train-auc:0.79750	test-auc:0.79663	valid-auc:0.79025
# [11]	train-auc:0.79762	test-auc:0.79673	valid-auc:0.79081
# [12]	train-auc:0.79944	test-auc:0.79802	valid-auc:0.79232
# [13]	train-auc:0.80143	test-auc:0.79915	valid-auc:0.79384
# [14]	train-auc:0.80237	test-auc:0.80022	valid-auc:0.79477
# [15]	train-auc:0.80329	test-auc:0.80071	valid-auc:0.79550
# [16]	train-auc:0.80405	test-auc:0.80099	valid-auc:0.79581
# [17]	train-auc:0.80519	test-auc:0.80206	valid-auc:0.79606
# [18]	train-auc:0.80538	test-auc:0.80232	valid-auc:0.79631
# [19]	train-auc:0.80579	test-auc:0.80245	valid-auc:0.79661
# [20]	train-auc:0.80629	test-auc:0.80286	valid-auc:0.79719
# [21]	train-auc:0.80796	test-auc:0.80406	valid-auc:0.79909
# [22]	train-auc:0.80823	test-auc:0.80422	valid-auc:0.79927
# [23]	train-auc:0.80872	test-auc:0.80439	valid-auc:0.79955
# [24]	train-auc:0.80898	test-auc:0.80440	valid-auc:0.79939
# [25]	train-auc:0.81073	test-auc:0.80524	valid-auc:0.80059
# [26]	train-auc:0.81230	test-auc:0.80633	valid-auc:0.80153
# [27]	train-auc:0.81230	test-auc:0.80636	valid-auc:0.80162
# [28]	train-auc:0.81391	test-auc:0.80671	valid-auc:0.80283
# [29]	train-auc:0.81527	test-auc:0.80699	valid-auc:0.80312
# [30]	train-auc:0.81543	test-auc:0.80702	valid-auc:0.80325
# [31]	train-auc:0.81580	test-auc:0.80698	valid-auc:0.80366
# [32]	train-auc:0.81623	test-auc:0.80723	valid-auc:0.80393
# [33]	train-auc:0.81677	test-auc:0.80728	valid-auc:0.80428
# [34]	train-auc:0.81755	test-auc:0.80731	valid-auc:0.80433
# [35]	train-auc:0.81775	test-auc:0.80754	valid-auc:0.80479
# [36]	train-auc:0.81820	test-auc:0.80743	valid-auc:0.80533
# [37]	train-auc:0.81891	test-auc:0.80773	valid-auc:0.80514
# [38]	train-auc:0.81936	test-auc:0.80798	valid-auc:0.80532
# [39]	train-auc:0.82055	test-auc:0.80786	valid-auc:0.80597
# [40]	train-auc:0.82122	test-auc:0.80858	valid-auc:0.80629
# [41]	train-auc:0.82126	test-auc:0.80858	valid-auc:0.80635
# [42]	train-auc:0.82181	test-auc:0.80852	valid-auc:0.80631
# [43]	train-auc:0.82199	test-auc:0.80854	valid-auc:0.80635
# [44]	train-auc:0.82294	test-auc:0.80947	valid-auc:0.80736
# [45]	train-auc:0.82389	test-auc:0.80985	valid-auc:0.80773
# [46]	train-auc:0.82496	test-auc:0.80971	valid-auc:0.80735
# [47]	train-auc:0.82549	test-auc:0.81031	valid-auc:0.80754
# [48]	train-auc:0.82557	test-auc:0.81028	valid-auc:0.80762
# [49]	train-auc:0.82583	test-auc:0.81033	valid-auc:0.80774
# [50]	train-auc:0.82641	test-auc:0.81077	valid-auc:0.80813
# [51]	train-auc:0.82660	test-auc:0.81081	valid-auc:0.80827
# [52]	train-auc:0.82675	test-auc:0.81096	valid-auc:0.80827
# [53]	train-auc:0.82684	test-auc:0.81101	valid-auc:0.80822
# [54]	train-auc:0.82707	test-auc:0.81125	valid-auc:0.80825
# [55]	train-auc:0.82729	test-auc:0.81114	valid-auc:0.80859
# [56]	train-auc:0.82752	test-auc:0.81115	valid-auc:0.80874
# [57]	train-auc:0.82860	test-auc:0.81112	valid-auc:0.80863
# [58]	train-auc:0.82884	test-auc:0.81128	valid-auc:0.80863
# [59]	train-auc:0.82918	test-auc:0.81156	valid-auc:0.80863
# [60]	train-auc:0.82947	test-auc:0.81157	valid-auc:0.80885
# [61]	train-auc:0.82998	test-auc:0.81134	valid-auc:0.80909
# [62]	train-auc:0.83067	test-auc:0.81120	valid-auc:0.80894
# [63]	train-auc:0.83061	test-auc:0.81118	valid-auc:0.80893
# [64]	train-auc:0.83140	test-auc:0.81108	valid-auc:0.80955
# [65]	train-auc:0.83209	test-auc:0.81088	valid-auc:0.80967
# [66]	train-auc:0.83226	test-auc:0.81093	valid-auc:0.80973
# [67]	train-auc:0.83241	test-auc:0.81090	valid-auc:0.80980
# [68]	train-auc:0.83289	test-auc:0.81097	valid-auc:0.80946
# [69]	train-auc:0.83369	test-auc:0.81111	valid-auc:0.80940
# [70]	train-auc:0.83414	test-auc:0.81112	valid-auc:0.80946
# [71]	train-auc:0.83436	test-auc:0.81121	valid-auc:0.80940
# [72]	train-auc:0.83446	test-auc:0.81122	valid-auc:0.80943
# [73]	train-auc:0.83457	test-auc:0.81122	valid-auc:0.80945
# [74]	train-auc:0.83479	test-auc:0.81137	valid-auc:0.80944
# [75]	train-auc:0.83514	test-auc:0.81161	valid-auc:0.80945
# [76]	train-auc:0.83543	test-auc:0.81145	valid-auc:0.80952
# [77]	train-auc:0.83558	test-auc:0.81140	valid-auc:0.80968

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster.best_score
best_iteration = booster.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in booster.get_score(importance_type = importance_type).items()], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = 17
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:20])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:20])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=12,
    verbosity=1,
    eval_metric='auc',
    use_label_encoder=False,
    early_stopping_rounds=10,
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.75533	validation_1-auc:0.75971	validation_2-auc:0.74696
# [1]	validation_0-auc:0.77571	validation_1-auc:0.77279	validation_2-auc:0.76644
# [2]	validation_0-auc:0.78522	validation_1-auc:0.78015	validation_2-auc:0.77605
# [3]	validation_0-auc:0.78980	validation_1-auc:0.78418	validation_2-auc:0.77833
# [4]	validation_0-auc:0.79962	validation_1-auc:0.79262	validation_2-auc:0.78682
# [5]	validation_0-auc:0.80282	validation_1-auc:0.79481	validation_2-auc:0.78939
# [6]	validation_0-auc:0.80481	validation_1-auc:0.79667	validation_2-auc:0.79193
# [7]	validation_0-auc:0.81011	validation_1-auc:0.80134	validation_2-auc:0.79579
# [8]	validation_0-auc:0.81493	validation_1-auc:0.80348	validation_2-auc:0.79984
# [9]	validation_0-auc:0.81595	validation_1-auc:0.80412	validation_2-auc:0.80091
# [10]	validation_0-auc:0.81699	validation_1-auc:0.80486	validation_2-auc:0.80160
# [11]	validation_0-auc:0.82035	validation_1-auc:0.80779	validation_2-auc:0.80555
# [12]	validation_0-auc:0.82185	validation_1-auc:0.80834	validation_2-auc:0.80574
# [13]	validation_0-auc:0.82316	validation_1-auc:0.80870	validation_2-auc:0.80675
# [14]	validation_0-auc:0.82366	validation_1-auc:0.80946	validation_2-auc:0.80741
# [15]	validation_0-auc:0.82382	validation_1-auc:0.80951	validation_2-auc:0.80738
# [16]	validation_0-auc:0.82522	validation_1-auc:0.80967	validation_2-auc:0.80828
# [17]	validation_0-auc:0.82717	validation_1-auc:0.81068	validation_2-auc:0.80893
# [18]	validation_0-auc:0.82829	validation_1-auc:0.81100	validation_2-auc:0.80943
# [19]	validation_0-auc:0.82900	validation_1-auc:0.81101	validation_2-auc:0.80982
# [20]	validation_0-auc:0.82956	validation_1-auc:0.81104	validation_2-auc:0.80977
# [21]	validation_0-auc:0.83021	validation_1-auc:0.81103	validation_2-auc:0.80999
# [22]	validation_0-auc:0.83089	validation_1-auc:0.81097	validation_2-auc:0.81009
# [23]	validation_0-auc:0.83375	validation_1-auc:0.81135	validation_2-auc:0.81052
# [24]	validation_0-auc:0.83706	validation_1-auc:0.81136	validation_2-auc:0.81066
# [25]	validation_0-auc:0.83742	validation_1-auc:0.81158	validation_2-auc:0.81057
# [26]	validation_0-auc:0.83775	validation_1-auc:0.81181	validation_2-auc:0.81047
# [27]	validation_0-auc:0.83832	validation_1-auc:0.81150	validation_2-auc:0.81023
# [28]	validation_0-auc:0.83951	validation_1-auc:0.81194	validation_2-auc:0.81058
# [29]	validation_0-auc:0.84004	validation_1-auc:0.81222	validation_2-auc:0.81071
# [30]	validation_0-auc:0.84045	validation_1-auc:0.81245	validation_2-auc:0.81093
# [31]	validation_0-auc:0.84166	validation_1-auc:0.81309	validation_2-auc:0.81089
# [32]	validation_0-auc:0.84348	validation_1-auc:0.81358	validation_2-auc:0.81138
# [33]	validation_0-auc:0.84388	validation_1-auc:0.81360	validation_2-auc:0.81124
# [34]	validation_0-auc:0.84539	validation_1-auc:0.81347	validation_2-auc:0.81153
# [35]	validation_0-auc:0.84743	validation_1-auc:0.81258	validation_2-auc:0.81081
# [36]	validation_0-auc:0.84775	validation_1-auc:0.81280	validation_2-auc:0.81083
# [37]	validation_0-auc:0.84916	validation_1-auc:0.81280	validation_2-auc:0.81112
# [38]	validation_0-auc:0.85146	validation_1-auc:0.81327	validation_2-auc:0.81166
# [39]	validation_0-auc:0.85298	validation_1-auc:0.81280	validation_2-auc:0.81110
# [40]	validation_0-auc:0.85302	validation_1-auc:0.81276	validation_2-auc:0.81105
# [41]	validation_0-auc:0.85362	validation_1-auc:0.81273	validation_2-auc:0.81136
# [42]	validation_0-auc:0.85400	validation_1-auc:0.81268	validation_2-auc:0.81157
# [43]	validation_0-auc:0.85489	validation_1-auc:0.81288	validation_2-auc:0.81160
# [44]	validation_0-auc:0.85522	validation_1-auc:0.81290	validation_2-auc:0.81204
# [45]	validation_0-auc:0.85559	validation_1-auc:0.81305	validation_2-auc:0.81213
# [46]	validation_0-auc:0.85604	validation_1-auc:0.81317	validation_2-auc:0.81193
# [47]	validation_0-auc:0.85712	validation_1-auc:0.81317	validation_2-auc:0.81177
# [48]	validation_0-auc:0.85832	validation_1-auc:0.81336	validation_2-auc:0.81169
# [49]	validation_0-auc:0.85867	validation_1-auc:0.81327	validation_2-auc:0.81156
# [50]	validation_0-auc:0.85985	validation_1-auc:0.81282	validation_2-auc:0.81110
# [51]	validation_0-auc:0.86078	validation_1-auc:0.81271	validation_2-auc:0.81161
# [52]	validation_0-auc:0.86112	validation_1-auc:0.81260	validation_2-auc:0.81174
# [53]	validation_0-auc:0.86155	validation_1-auc:0.81276	validation_2-auc:0.81184
# [54]	validation_0-auc:0.86216	validation_1-auc:0.81261	validation_2-auc:0.81200
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=12, ...)

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
params={
    'eta': 0.1,
    'max_depth': 3,
    'subsample': 0.7,
    'colsample_bytree': 0.7,

    'eval_metric': 'auc',
    'objective': 'binary:logistic' ,
    'booster': 'gbtree',
    'tree_method': 'exact',

    'seed': 12
}

skf = StratifiedKFold(n_splits = 2, shuffle = True, random_state = 12)

X = data[cols_pred].values
y = data[col_target].values
data['cv_score'] = -1
cv_res = []
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    evals_result = {}
    booster = xgb.train(
        params = params,
        dtrain = xgb.DMatrix(X_train, y_train),
        num_boost_round = 1000,
        evals = (
            (xgb.DMatrix(X_train, y_train), 'train'),
            (xgb.DMatrix(X_test, y_test), 'test'),
        ),
        evals_result = evals_result,
        early_stopping_rounds = 10,
        verbose_eval = True
    )
    
    gini_train = 2 * roc_auc_score(y_train, booster.predict(xgb.DMatrix(X_train))) - 1
    gini_test  = 2 * roc_auc_score(y_test,  booster.predict(xgb.DMatrix(X_test)))  - 1
    best_iteration = booster.best_iteration
    
    cv_res += [(gini_train, gini_test, best_iteration)]
    
    data.iloc[test_index, list(data.columns).index('cv_score')] = list(booster.predict(xgb.DMatrix(X_test), iteration_range=(0, booster.best_iteration)))
# Out:
# [0]	train-auc:0.68184	test-auc:0.68659
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\3701129152.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['cv_score'] = -1
# [1]	train-auc:0.69771	test-auc:0.69836
# [2]	train-auc:0.73741	test-auc:0.73900
# [3]	train-auc:0.73544	test-auc:0.73710
# [4]	train-auc:0.74288	test-auc:0.74366
# [5]	train-auc:0.75457	test-auc:0.75406
# [6]	train-auc:0.75583	test-auc:0.75519
# [7]	train-auc:0.76316	test-auc:0.76119
# [8]	train-auc:0.76842	test-auc:0.76640
# [9]	train-auc:0.76824	test-auc:0.76558
# [10]	train-auc:0.76977	test-auc:0.76705
# [11]	train-auc:0.76959	test-auc:0.76586
# [12]	train-auc:0.76939	test-auc:0.76579
# [13]	train-auc:0.77136	test-auc:0.76810
# [14]	train-auc:0.77275	test-auc:0.76952
# [15]	train-auc:0.77463	test-auc:0.77130
# [16]	train-auc:0.77664	test-auc:0.77294
# [17]	train-auc:0.77668	test-auc:0.77322
# [18]	train-auc:0.77782	test-auc:0.77448
# [19]	train-auc:0.77702	test-auc:0.77346
# [20]	train-auc:0.77758	test-auc:0.77358
# [21]	train-auc:0.77722	test-auc:0.77368
# [22]	train-auc:0.77834	test-auc:0.77490
# [23]	train-auc:0.78109	test-auc:0.77732
# [24]	train-auc:0.78122	test-auc:0.77764
# [25]	train-auc:0.78300	test-auc:0.77923
# [26]	train-auc:0.78394	test-auc:0.78031
# [27]	train-auc:0.78499	test-auc:0.78132
# [28]	train-auc:0.78632	test-auc:0.78223
# [29]	train-auc:0.78727	test-auc:0.78285
# [30]	train-auc:0.78783	test-auc:0.78364
# [31]	train-auc:0.78798	test-auc:0.78346
# [32]	train-auc:0.78822	test-auc:0.78379
# [33]	train-auc:0.78907	test-auc:0.78456
# [34]	train-auc:0.78958	test-auc:0.78485
# [35]	train-auc:0.78988	test-auc:0.78468
# [36]	train-auc:0.79063	test-auc:0.78541
# [37]	train-auc:0.79137	test-auc:0.78577
# [38]	train-auc:0.79198	test-auc:0.78637
# [39]	train-auc:0.79249	test-auc:0.78690
# [40]	train-auc:0.79273	test-auc:0.78722
# [41]	train-auc:0.79283	test-auc:0.78723
# [42]	train-auc:0.79329	test-auc:0.78758
# [43]	train-auc:0.79427	test-auc:0.78863
# [44]	train-auc:0.79503	test-auc:0.78955
# [45]	train-auc:0.79501	test-auc:0.78940
# [46]	train-auc:0.79513	test-auc:0.78954
# [47]	train-auc:0.79551	test-auc:0.79004
# [48]	train-auc:0.79627	test-auc:0.79082
# [49]	train-auc:0.79632	test-auc:0.79099
# [50]	train-auc:0.79669	test-auc:0.79141
# [51]	train-auc:0.79694	test-auc:0.79161
# [52]	train-auc:0.79726	test-auc:0.79204
# [53]	train-auc:0.79758	test-auc:0.79221
# [54]	train-auc:0.79760	test-auc:0.79209
# [55]	train-auc:0.79813	test-auc:0.79253
# [56]	train-auc:0.79875	test-auc:0.79320
# [57]	train-auc:0.79893	test-auc:0.79336
# [58]	train-auc:0.79902	test-auc:0.79332
# [59]	train-auc:0.79943	test-auc:0.79368
# [60]	train-auc:0.79942	test-auc:0.79369
# [61]	train-auc:0.79968	test-auc:0.79371
# [62]	train-auc:0.79991	test-auc:0.79383
# [63]	train-auc:0.80004	test-auc:0.79390
# [64]	train-auc:0.80012	test-auc:0.79400
# [65]	train-auc:0.80061	test-auc:0.79431
# [66]	train-auc:0.80083	test-auc:0.79441
# [67]	train-auc:0.80097	test-auc:0.79455
# [68]	train-auc:0.80115	test-auc:0.79453
# [69]	train-auc:0.80141	test-auc:0.79461
# [70]	train-auc:0.80156	test-auc:0.79474
# [71]	train-auc:0.80168	test-auc:0.79481
# [72]	train-auc:0.80191	test-auc:0.79496
# [73]	train-auc:0.80236	test-auc:0.79506
# [74]	train-auc:0.80277	test-auc:0.79540
# [75]	train-auc:0.80315	test-auc:0.79566
# [76]	train-auc:0.80323	test-auc:0.79566
# [77]	train-auc:0.80370	test-auc:0.79596
# [78]	train-auc:0.80379	test-auc:0.79591
# [79]	train-auc:0.80391	test-auc:0.79601
# [80]	train-auc:0.80406	test-auc:0.79618
# [81]	train-auc:0.80424	test-auc:0.79619
# [82]	train-auc:0.80442	test-auc:0.79626
# [83]	train-auc:0.80460	test-auc:0.79633
# [84]	train-auc:0.80477	test-auc:0.79635
# [85]	train-auc:0.80506	test-auc:0.79659
# [86]	train-auc:0.80519	test-auc:0.79663
# [87]	train-auc:0.80520	test-auc:0.79664
# [88]	train-auc:0.80527	test-auc:0.79672
# [89]	train-auc:0.80546	test-auc:0.79680
# [90]	train-auc:0.80567	test-auc:0.79682
# [91]	train-auc:0.80596	test-auc:0.79703
# [92]	train-auc:0.80608	test-auc:0.79709
# [93]	train-auc:0.80618	test-auc:0.79725
# [94]	train-auc:0.80639	test-auc:0.79735
# [95]	train-auc:0.80649	test-auc:0.79737
# [96]	train-auc:0.80655	test-auc:0.79749
# [97]	train-auc:0.80676	test-auc:0.79768
# [98]	train-auc:0.80682	test-auc:0.79765
# [99]	train-auc:0.80701	test-auc:0.79760
# [100]	train-auc:0.80704	test-auc:0.79760
# [101]	train-auc:0.80712	test-auc:0.79762
# [102]	train-auc:0.80753	test-auc:0.79791
# [103]	train-auc:0.80763	test-auc:0.79798
# [104]	train-auc:0.80787	test-auc:0.79805
# [105]	train-auc:0.80814	test-auc:0.79807
# [106]	train-auc:0.80854	test-auc:0.79822
# [107]	train-auc:0.80857	test-auc:0.79821
# [108]	train-auc:0.80864	test-auc:0.79816
# [109]	train-auc:0.80877	test-auc:0.79820
# [110]	train-auc:0.80902	test-auc:0.79840
# [111]	train-auc:0.80913	test-auc:0.79847
# [112]	train-auc:0.80923	test-auc:0.79849
# [113]	train-auc:0.80932	test-auc:0.79850
# [114]	train-auc:0.80952	test-auc:0.79876
# [115]	train-auc:0.80973	test-auc:0.79897
# [116]	train-auc:0.80979	test-auc:0.79896
# [117]	train-auc:0.81007	test-auc:0.79923
# [118]	train-auc:0.81040	test-auc:0.79940
# [119]	train-auc:0.81059	test-auc:0.79955
# [120]	train-auc:0.81067	test-auc:0.79947
# [121]	train-auc:0.81092	test-auc:0.79966
# [122]	train-auc:0.81111	test-auc:0.79988
# [123]	train-auc:0.81108	test-auc:0.79975
# [124]	train-auc:0.81134	test-auc:0.79985
# [125]	train-auc:0.81141	test-auc:0.79987
# [126]	train-auc:0.81166	test-auc:0.80016
# [127]	train-auc:0.81188	test-auc:0.80018
# [128]	train-auc:0.81214	test-auc:0.80026
# [129]	train-auc:0.81229	test-auc:0.80031
# [130]	train-auc:0.81233	test-auc:0.80033
# [131]	train-auc:0.81250	test-auc:0.80050
# [132]	train-auc:0.81257	test-auc:0.80046
# [133]	train-auc:0.81285	test-auc:0.80057
# [134]	train-auc:0.81294	test-auc:0.80060
# [135]	train-auc:0.81314	test-auc:0.80071
# [136]	train-auc:0.81342	test-auc:0.80072
# [137]	train-auc:0.81357	test-auc:0.80087
# [138]	train-auc:0.81378	test-auc:0.80103
# [139]	train-auc:0.81413	test-auc:0.80127
# [140]	train-auc:0.81428	test-auc:0.80127
# [141]	train-auc:0.81432	test-auc:0.80131
# [142]	train-auc:0.81437	test-auc:0.80130
# [143]	train-auc:0.81465	test-auc:0.80146
# [144]	train-auc:0.81495	test-auc:0.80146
# [145]	train-auc:0.81499	test-auc:0.80147
# [146]	train-auc:0.81505	test-auc:0.80150
# [147]	train-auc:0.81518	test-auc:0.80148
# [148]	train-auc:0.81531	test-auc:0.80138
# [149]	train-auc:0.81536	test-auc:0.80137
# [150]	train-auc:0.81539	test-auc:0.80139
# [151]	train-auc:0.81541	test-auc:0.80144
# [152]	train-auc:0.81556	test-auc:0.80144
# [153]	train-auc:0.81560	test-auc:0.80139
# [154]	train-auc:0.81567	test-auc:0.80140
# [155]	train-auc:0.81594	test-auc:0.80161
# [156]	train-auc:0.81604	test-auc:0.80155
# [157]	train-auc:0.81627	test-auc:0.80167
# [158]	train-auc:0.81631	test-auc:0.80166
# [159]	train-auc:0.81649	test-auc:0.80178
# [160]	train-auc:0.81659	test-auc:0.80186
# [161]	train-auc:0.81672	test-auc:0.80197
# [162]	train-auc:0.81686	test-auc:0.80199
# [163]	train-auc:0.81695	test-auc:0.80196
# [164]	train-auc:0.81730	test-auc:0.80203
# [165]	train-auc:0.81756	test-auc:0.80215
# [166]	train-auc:0.81760	test-auc:0.80213
# [167]	train-auc:0.81764	test-auc:0.80210
# [168]	train-auc:0.81777	test-auc:0.80222
# [169]	train-auc:0.81799	test-auc:0.80208
# [170]	train-auc:0.81807	test-auc:0.80207
# [171]	train-auc:0.81826	test-auc:0.80209
# [172]	train-auc:0.81843	test-auc:0.80221
# [173]	train-auc:0.81856	test-auc:0.80236
# [174]	train-auc:0.81867	test-auc:0.80243
# [175]	train-auc:0.81885	test-auc:0.80255
# [176]	train-auc:0.81886	test-auc:0.80255
# [177]	train-auc:0.81900	test-auc:0.80260
# [178]	train-auc:0.81911	test-auc:0.80261
# [179]	train-auc:0.81918	test-auc:0.80266
# [180]	train-auc:0.81924	test-auc:0.80269
# [181]	train-auc:0.81941	test-auc:0.80271
# [182]	train-auc:0.81955	test-auc:0.80276
# [183]	train-auc:0.81965	test-auc:0.80277
# [184]	train-auc:0.81978	test-auc:0.80281
# [185]	train-auc:0.81997	test-auc:0.80294
# [186]	train-auc:0.81995	test-auc:0.80295
# [187]	train-auc:0.82004	test-auc:0.80296
# [188]	train-auc:0.82017	test-auc:0.80299
# [189]	train-auc:0.82017	test-auc:0.80300
# [190]	train-auc:0.82026	test-auc:0.80304
# [191]	train-auc:0.82064	test-auc:0.80317
# [192]	train-auc:0.82065	test-auc:0.80318
# [193]	train-auc:0.82085	test-auc:0.80329
# [194]	train-auc:0.82085	test-auc:0.80331
# [195]	train-auc:0.82085	test-auc:0.80330
# [196]	train-auc:0.82094	test-auc:0.80329
# [197]	train-auc:0.82106	test-auc:0.80330
# [198]	train-auc:0.82123	test-auc:0.80333
# [199]	train-auc:0.82133	test-auc:0.80334
# [200]	train-auc:0.82151	test-auc:0.80348
# [201]	train-auc:0.82169	test-auc:0.80352
# [202]	train-auc:0.82170	test-auc:0.80348
# [203]	train-auc:0.82171	test-auc:0.80351
# [204]	train-auc:0.82183	test-auc:0.80354
# [205]	train-auc:0.82199	test-auc:0.80368
# [206]	train-auc:0.82213	test-auc:0.80374
# [207]	train-auc:0.82218	test-auc:0.80369
# [208]	train-auc:0.82237	test-auc:0.80378
# [209]	train-auc:0.82241	test-auc:0.80376
# [210]	train-auc:0.82255	test-auc:0.80374
# [211]	train-auc:0.82262	test-auc:0.80374
# [212]	train-auc:0.82287	test-auc:0.80391
# [213]	train-auc:0.82300	test-auc:0.80387
# [214]	train-auc:0.82313	test-auc:0.80395
# [215]	train-auc:0.82324	test-auc:0.80398
# [216]	train-auc:0.82327	test-auc:0.80396
# [217]	train-auc:0.82337	test-auc:0.80400
# [218]	train-auc:0.82343	test-auc:0.80402
# [219]	train-auc:0.82360	test-auc:0.80406
# [220]	train-auc:0.82376	test-auc:0.80409
# [221]	train-auc:0.82384	test-auc:0.80417
# [222]	train-auc:0.82399	test-auc:0.80423
# [223]	train-auc:0.82408	test-auc:0.80432
# [224]	train-auc:0.82409	test-auc:0.80434
# [225]	train-auc:0.82430	test-auc:0.80447
# [226]	train-auc:0.82444	test-auc:0.80448
# [227]	train-auc:0.82450	test-auc:0.80440
# [228]	train-auc:0.82460	test-auc:0.80445
# [229]	train-auc:0.82462	test-auc:0.80445
# [230]	train-auc:0.82473	test-auc:0.80442
# [231]	train-auc:0.82490	test-auc:0.80444
# [232]	train-auc:0.82513	test-auc:0.80450
# [233]	train-auc:0.82532	test-auc:0.80449
# [234]	train-auc:0.82539	test-auc:0.80450
# [235]	train-auc:0.82548	test-auc:0.80452
# [236]	train-auc:0.82554	test-auc:0.80452
# [237]	train-auc:0.82563	test-auc:0.80446
# [238]	train-auc:0.82581	test-auc:0.80446
# [239]	train-auc:0.82599	test-auc:0.80461
# [240]	train-auc:0.82612	test-auc:0.80472
# [241]	train-auc:0.82624	test-auc:0.80475
# [242]	train-auc:0.82634	test-auc:0.80473
# [243]	train-auc:0.82640	test-auc:0.80474
# [244]	train-auc:0.82653	test-auc:0.80476
# [245]	train-auc:0.82661	test-auc:0.80480
# [246]	train-auc:0.82674	test-auc:0.80472
# [247]	train-auc:0.82694	test-auc:0.80478
# [248]	train-auc:0.82703	test-auc:0.80474
# [249]	train-auc:0.82708	test-auc:0.80473
# [250]	train-auc:0.82721	test-auc:0.80475
# [251]	train-auc:0.82732	test-auc:0.80471
# [252]	train-auc:0.82734	test-auc:0.80470
# [253]	train-auc:0.82745	test-auc:0.80462
# [254]	train-auc:0.82757	test-auc:0.80464
# [0]	train-auc:0.68044	test-auc:0.67160
# [1]	train-auc:0.70974	test-auc:0.70232
# C:\Users\matej\AppData\Local\Temp\ipykernel_36524\3701129152.py:45: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.70218825, 0.24270456, 0.13283649, 0.08296757, 0.45450422, 0.23857516, 0.27686483, 0.4705725, 0.22937018, 0.17872573, 0.50364655, 0.38478932, 0.7037219, 0.35578936, 0.46088144, 0.5369941, 0.078582995, 0.6511768, 0.09252148, 0.5255363, 0.28236115, 0.51300853, 0.20874026, 0.032279946, 0.08554052, 0.53335845, 0.047871497, 0.20248006, 0.036231134, 0.6305208, 0.1153703, 0.26978675, 0.16569614, 0.016015217, 0.006436776, 0.36708432, 0.2686443, 0.75559705, 0.46432075, 0.6054761, 0.3438978, 0.29949194, 0.69425005, 0.22507477, 0.48142183, 0.123064995, 0.32831025, 0.12048512, 0.46606594, 0.50503266, 0.71135753, 0.13187787, 0.2450337, 0.04693411, 0.27673003, 0.30054757, 0.50870913, 0.06402794, 0.7759401, 0.2084978, 0.52872825, 0.17740537, 0.32957, 0.2439985, 0.49013937, 0.045052096, 0.10765801, 0.6164307, 0.27576938, 0.7965255, 0.389071, 0.2532526, 0.37612855, 0.0957438, 0.793248, 0.05650431, 0.9584628, 0.2541693, 0.10310359, 0.2757597, 0.2926837, 0.19233084, 0.18885027, 0.13946052, 0.47298408, 0.39376885, 0.10326121, 0.05935285, 0.4693002, 0.7451588, 0.47534522, 0.23791817, 0.5691259, 0.5834115, 0.24545945, 0.074386515, 0.44901732, 0.3120786, 0.07938628, 0.17581823, 0.16966547, 0.04779243, 0.09068015, 0.24526028, 0.41004676, 0.24023728, 0.60146534, 0.4481025, 0.5489161, 0.5508391, 0.22956817, 0.50354594, 0.20886081, 0.48699015, 0.3328744, 0.4275478, 0.6988294, 0.0034252862, 0.0836154, 0.6206745, 0.48227698, 0.3505946, 0.04126899, 0.4511746, 0.06157551, 0.4104087, 0.45603386, 0.34293216, 0.08637454, 0.33109102, 0.004669285, 0.43114743, 0.34496048, 0.33864254, 0.030368667, 0.34936082, 0.8636387, 0.90574664, 0.062303368, 0.7120511, 0.37182558, 0.19444773, 0.1652842, 0.025584875, 0.7246838, 0.3640439, 0.5209354, 0.7605202, 0.76117945, 0.19539028, 0.5448255, 0.764685, 0.39758098, 0.07492102, 0.29392466, 0.113227785, 0.337448, 0.17962085, 0.46757835, 0.3783866, 0.6364331, 0.12945272, 0.83812636, 0.20548928, 0.13393375, 0.748945, 0.5621172, 0.25359565, 0.2775463, 0.5964091, 0.15612887, 0.16418077, 0.4246348, 0.80004114, 0.5269521, 0.18487726, 0.46812963, 0.70000523, 0.68271744, 0.3163004, 0.5264392, 0.63514495, 0.41900992, 0.006092429, 0.737001, 0.11724982, 0.4576063, 0.58736503, 0.090389356, 0.20673043, 0.18113138, 0.013474866, 0.6818103, 0.3433524, 0.038498297, 0.5809054, 0.2549354, 0.43074724, 0.081732586, 0.011364875, 0.16556314, 0.03462095, 0.6735153, 0.0607321, 0.47683743, 0.6494005, 0.119229145, 0.10794141, 0.48169166, 0.26943278, 0.14951196, 0.17102939, 0.93582314, 0.17689836, 0.31004065, 0.5722586, 0.0263322, 0.18501358, 0.4221962, 0.46223268, 0.04689477, 0.34313244, 0.009222336, 0.22031559, 0.6165986, 0.6399547, 0.42600468, 0.12725307, 0.75264364, 0.108270064, 0.07477512, 0.18425885, 0.017315237, 0.28593254, 0.55089617, 0.21618338, 0.43277717, 0.14694162, 0.34194258, 0.02025309, 0.21801682, 0.4755064, 0.3946976, 0.17479587, 0.43114948, 0.54805535, 0.28147078, 0.3740064, 0.40893266, 0.094817616, 0.2540857, 0.18958849, 0.09424793, 0.5152346, 0.013339901, 0.592112, 0.27896026, 0.023486312, 0.23725903, 0.21027833, 0.019436767, 0.3474221, 0.08295728, 0.15429646, 0.6428018, 0.29106882, 0.7234216, 0.17290083, 0.56255656, 0.7225609, 0.08335983, 0.18361263, 0.19506086, 0.56313, 0.15121323, 0.018636348, 0.5176765, 0.70973015, 0.4263277, 0.23352, 0.36176506, 0.50551844, 0.16856065, 0.46148598, 0.41729453, 0.32921863, 0.39842296, 0.43556494, 0.48861375, 0.14801584, 0.1905706, 0.36983517, 0.067798674, 0.7471004, 0.2445983, 0.67872894, 0.024735691, 0.07416274, 0.9492084, 0.022297164, 0.74388975, 0.52990216, 0.514147, 0.020807404, 0.30886745, 0.36033657, 0.25969195, 0.04280949, 0.19303624, 0.665058, 0.35681525, 0.49073488, 0.76375246, 0.2849842, 0.14859796, 0.07072193, 0.25081256, 0.33462548, 0.11462119, 0.65572774, 0.09290955, 0.20988294, 0.1963538, 0.7 ...
#   data.iloc[test_index, list(data.columns).index('cv_score')] = list(booster.predict(xgb.DMatrix(X_test), iteration_range=(0, booster.best_iteration)))
# [2]	train-auc:0.73120	test-auc:0.72461
# [3]	train-auc:0.74092	test-auc:0.73608
# [4]	train-auc:0.74320	test-auc:0.73849
# [5]	train-auc:0.74076	test-auc:0.73587
# [6]	train-auc:0.74861	test-auc:0.74147
# [7]	train-auc:0.75393	test-auc:0.74532
# [8]	train-auc:0.75810	test-auc:0.74853
# [9]	train-auc:0.75949	test-auc:0.74968
# [10]	train-auc:0.76212	test-auc:0.75210
# [11]	train-auc:0.76347	test-auc:0.75439
# [12]	train-auc:0.76833	test-auc:0.76034
# [13]	train-auc:0.76943	test-auc:0.76122
# [14]	train-auc:0.76978	test-auc:0.76169
# [15]	train-auc:0.77217	test-auc:0.76433
# [16]	train-auc:0.77339	test-auc:0.76525
# [17]	train-auc:0.77698	test-auc:0.76849
# [18]	train-auc:0.77794	test-auc:0.76958
# [19]	train-auc:0.77893	test-auc:0.77149
# [20]	train-auc:0.78009	test-auc:0.77228
# [21]	train-auc:0.78117	test-auc:0.77362
# [22]	train-auc:0.78192	test-auc:0.77456
# [23]	train-auc:0.78284	test-auc:0.77531
# [24]	train-auc:0.78299	test-auc:0.77547
# [25]	train-auc:0.78352	test-auc:0.77536
# [26]	train-auc:0.78407	test-auc:0.77590
# [27]	train-auc:0.78504	test-auc:0.77635
# [28]	train-auc:0.78577	test-auc:0.77717
# [29]	train-auc:0.78669	test-auc:0.77740
# [30]	train-auc:0.78756	test-auc:0.77838
# [31]	train-auc:0.78847	test-auc:0.77924
# [32]	train-auc:0.78825	test-auc:0.77908
# [33]	train-auc:0.78827	test-auc:0.77914
# [34]	train-auc:0.78903	test-auc:0.77944
# [35]	train-auc:0.78952	test-auc:0.78016
# [36]	train-auc:0.78979	test-auc:0.78064
# [37]	train-auc:0.79055	test-auc:0.78129
# [38]	train-auc:0.79068	test-auc:0.78116
# [39]	train-auc:0.79093	test-auc:0.78147
# [40]	train-auc:0.79216	test-auc:0.78261
# [41]	train-auc:0.79253	test-auc:0.78291
# [42]	train-auc:0.79312	test-auc:0.78343
# [43]	train-auc:0.79311	test-auc:0.78346
# [44]	train-auc:0.79366	test-auc:0.78404
# [45]	train-auc:0.79403	test-auc:0.78443
# [46]	train-auc:0.79436	test-auc:0.78472
# [47]	train-auc:0.79517	test-auc:0.78546
# [48]	train-auc:0.79569	test-auc:0.78593
# [49]	train-auc:0.79592	test-auc:0.78598
# [50]	train-auc:0.79597	test-auc:0.78598
# [51]	train-auc:0.79621	test-auc:0.78639
# [52]	train-auc:0.79643	test-auc:0.78655
# [53]	train-auc:0.79731	test-auc:0.78719
# [54]	train-auc:0.79758	test-auc:0.78747
# [55]	train-auc:0.79825	test-auc:0.78809
# [56]	train-auc:0.79860	test-auc:0.78822
# [57]	train-auc:0.79925	test-auc:0.78911
# [58]	train-auc:0.79921	test-auc:0.78916
# [59]	train-auc:0.79954	test-auc:0.78953
# [60]	train-auc:0.80000	test-auc:0.79008
# [61]	train-auc:0.80019	test-auc:0.79030
# [62]	train-auc:0.80037	test-auc:0.79048
# [63]	train-auc:0.80051	test-auc:0.79049
# [64]	train-auc:0.80054	test-auc:0.79030
# [65]	train-auc:0.80078	test-auc:0.79039
# [66]	train-auc:0.80087	test-auc:0.79044
# [67]	train-auc:0.80103	test-auc:0.79064
# [68]	train-auc:0.80147	test-auc:0.79106
# [69]	train-auc:0.80148	test-auc:0.79116
# [70]	train-auc:0.80156	test-auc:0.79124
# [71]	train-auc:0.80172	test-auc:0.79118
# [72]	train-auc:0.80210	test-auc:0.79123
# [73]	train-auc:0.80237	test-auc:0.79130
# [74]	train-auc:0.80256	test-auc:0.79134
# [75]	train-auc:0.80271	test-auc:0.79151
# [76]	train-auc:0.80288	test-auc:0.79164
# [77]	train-auc:0.80294	test-auc:0.79173
# [78]	train-auc:0.80310	test-auc:0.79197
# [79]	train-auc:0.80311	test-auc:0.79194
# [80]	train-auc:0.80325	test-auc:0.79198
# [81]	train-auc:0.80345	test-auc:0.79220
# [82]	train-auc:0.80369	test-auc:0.79231
# [83]	train-auc:0.80372	test-auc:0.79240
# [84]	train-auc:0.80404	test-auc:0.79256
# [85]	train-auc:0.80410	test-auc:0.79259
# [86]	train-auc:0.80458	test-auc:0.79313
# [87]	train-auc:0.80466	test-auc:0.79326
# [88]	train-auc:0.80470	test-auc:0.79331
# [89]	train-auc:0.80493	test-auc:0.79331
# [90]	train-auc:0.80499	test-auc:0.79334
# [91]	train-auc:0.80542	test-auc:0.79369
# [92]	train-auc:0.80549	test-auc:0.79380
# [93]	train-auc:0.80568	test-auc:0.79412
# [94]	train-auc:0.80593	test-auc:0.79445
# [95]	train-auc:0.80601	test-auc:0.79455
# [96]	train-auc:0.80633	test-auc:0.79471
# [97]	train-auc:0.80645	test-auc:0.79477
# [98]	train-auc:0.80654	test-auc:0.79494
# [99]	train-auc:0.80679	test-auc:0.79497
# [100]	train-auc:0.80725	test-auc:0.79547
# [101]	train-auc:0.80731	test-auc:0.79548
# [102]	train-auc:0.80771	test-auc:0.79574
# [103]	train-auc:0.80789	test-auc:0.79587
# [104]	train-auc:0.80791	test-auc:0.79582
# [105]	train-auc:0.80843	test-auc:0.79609
# [106]	train-auc:0.80852	test-auc:0.79607
# [107]	train-auc:0.80857	test-auc:0.79608
# [108]	train-auc:0.80876	test-auc:0.79627
# [109]	train-auc:0.80884	test-auc:0.79634
# [110]	train-auc:0.80873	test-auc:0.79621
# [111]	train-auc:0.80875	test-auc:0.79623
# [112]	train-auc:0.80893	test-auc:0.79633
# [113]	train-auc:0.80904	test-auc:0.79654
# [114]	train-auc:0.80923	test-auc:0.79672
# [115]	train-auc:0.80933	test-auc:0.79676
# [116]	train-auc:0.80955	test-auc:0.79682
# [117]	train-auc:0.80972	test-auc:0.79685
# [118]	train-auc:0.80989	test-auc:0.79684
# [119]	train-auc:0.81007	test-auc:0.79689
# [120]	train-auc:0.81034	test-auc:0.79715
# [121]	train-auc:0.81044	test-auc:0.79718
# [122]	train-auc:0.81050	test-auc:0.79718
# [123]	train-auc:0.81083	test-auc:0.79731
# [124]	train-auc:0.81103	test-auc:0.79756
# [125]	train-auc:0.81132	test-auc:0.79755
# [126]	train-auc:0.81134	test-auc:0.79749
# [127]	train-auc:0.81165	test-auc:0.79759
# [128]	train-auc:0.81182	test-auc:0.79762
# [129]	train-auc:0.81189	test-auc:0.79769
# [130]	train-auc:0.81205	test-auc:0.79763
# [131]	train-auc:0.81231	test-auc:0.79773
# [132]	train-auc:0.81261	test-auc:0.79796
# [133]	train-auc:0.81270	test-auc:0.79797
# [134]	train-auc:0.81279	test-auc:0.79794
# [135]	train-auc:0.81281	test-auc:0.79798
# [136]	train-auc:0.81299	test-auc:0.79805
# [137]	train-auc:0.81310	test-auc:0.79815
# [138]	train-auc:0.81322	test-auc:0.79820
# [139]	train-auc:0.81320	test-auc:0.79822
# [140]	train-auc:0.81331	test-auc:0.79826
# [141]	train-auc:0.81335	test-auc:0.79827
# [142]	train-auc:0.81363	test-auc:0.79850
# [143]	train-auc:0.81374	test-auc:0.79853
# [144]	train-auc:0.81385	test-auc:0.79854
# [145]	train-auc:0.81420	test-auc:0.79861
# [146]	train-auc:0.81423	test-auc:0.79864
# [147]	train-auc:0.81427	test-auc:0.79866
# [148]	train-auc:0.81458	test-auc:0.79866
# [149]	train-auc:0.81454	test-auc:0.79875
# [150]	train-auc:0.81468	test-auc:0.79879
# [151]	train-auc:0.81486	test-auc:0.79885
# [152]	train-auc:0.81498	test-auc:0.79889
# [153]	train-auc:0.81514	test-auc:0.79891
# [154]	train-auc:0.81522	test-auc:0.79896
# [155]	train-auc:0.81530	test-auc:0.79884
# [156]	train-auc:0.81559	test-auc:0.79895
# [157]	train-auc:0.81567	test-auc:0.79895
# [158]	train-auc:0.81594	test-auc:0.79912
# [159]	train-auc:0.81611	test-auc:0.79907
# [160]	train-auc:0.81622	test-auc:0.79908
# [161]	train-auc:0.81624	test-auc:0.79911
# [162]	train-auc:0.81633	test-auc:0.79923
# [163]	train-auc:0.81655	test-auc:0.79939
# [164]	train-auc:0.81677	test-auc:0.79948
# [165]	train-auc:0.81679	test-auc:0.79949
# [166]	train-auc:0.81693	test-auc:0.79945
# [167]	train-auc:0.81697	test-auc:0.79941
# [168]	train-auc:0.81703	test-auc:0.79943
# [169]	train-auc:0.81717	test-auc:0.79950
# [170]	train-auc:0.81721	test-auc:0.79951
# [171]	train-auc:0.81722	test-auc:0.79951
# [172]	train-auc:0.81736	test-auc:0.79943
# [173]	train-auc:0.81750	test-auc:0.79951
# [174]	train-auc:0.81756	test-auc:0.79960
# [175]	train-auc:0.81791	test-auc:0.79979
# [176]	train-auc:0.81813	test-auc:0.79989
# [177]	train-auc:0.81813	test-auc:0.79990
# [178]	train-auc:0.81839	test-auc:0.80001
# [179]	train-auc:0.81864	test-auc:0.80015
# [180]	train-auc:0.81871	test-auc:0.80018
# [181]	train-auc:0.81892	test-auc:0.80024
# [182]	train-auc:0.81903	test-auc:0.80023
# [183]	train-auc:0.81937	test-auc:0.80044
# [184]	train-auc:0.81953	test-auc:0.80057
# [185]	train-auc:0.81955	test-auc:0.80062
# [186]	train-auc:0.81957	test-auc:0.80067
# [187]	train-auc:0.81961	test-auc:0.80070
# [188]	train-auc:0.81976	test-auc:0.80075
# [189]	train-auc:0.81976	test-auc:0.80075
# [190]	train-auc:0.81984	test-auc:0.80069
# [191]	train-auc:0.82005	test-auc:0.80084
# [192]	train-auc:0.82017	test-auc:0.80081
# [193]	train-auc:0.82023	test-auc:0.80077
# [194]	train-auc:0.82038	test-auc:0.80078
# [195]	train-auc:0.82044	test-auc:0.80075
# [196]	train-auc:0.82067	test-auc:0.80103
# [197]	train-auc:0.82084	test-auc:0.80126
# [198]	train-auc:0.82099	test-auc:0.80134
# [199]	train-auc:0.82101	test-auc:0.80133
# [200]	train-auc:0.82109	test-auc:0.80136
# [201]	train-auc:0.82119	test-auc:0.80144
# [202]	train-auc:0.82126	test-auc:0.80138
# [203]	train-auc:0.82143	test-auc:0.80140
# [204]	train-auc:0.82166	test-auc:0.80146
# [205]	train-auc:0.82169	test-auc:0.80149
# [206]	train-auc:0.82184	test-auc:0.80149
# [207]	train-auc:0.82201	test-auc:0.80154
# [208]	train-auc:0.82215	test-auc:0.80162
# [209]	train-auc:0.82215	test-auc:0.80166
# [210]	train-auc:0.82224	test-auc:0.80182
# [211]	train-auc:0.82240	test-auc:0.80184
# [212]	train-auc:0.82249	test-auc:0.80186
# [213]	train-auc:0.82263	test-auc:0.80185
# [214]	train-auc:0.82273	test-auc:0.80188
# [215]	train-auc:0.82293	test-auc:0.80197
# [216]	train-auc:0.82303	test-auc:0.80201
# [217]	train-auc:0.82316	test-auc:0.80188
# [218]	train-auc:0.82319	test-auc:0.80186
# [219]	train-auc:0.82331	test-auc:0.80199
# [220]	train-auc:0.82345	test-auc:0.80195
# [221]	train-auc:0.82346	test-auc:0.80196
# [222]	train-auc:0.82347	test-auc:0.80196
# [223]	train-auc:0.82352	test-auc:0.80194
# [224]	train-auc:0.82360	test-auc:0.80201
# [225]	train-auc:0.82373	test-auc:0.80213
# [226]	train-auc:0.82381	test-auc:0.80215
# [227]	train-auc:0.82397	test-auc:0.80211
# [228]	train-auc:0.82405	test-auc:0.80214
# [229]	train-auc:0.82424	test-auc:0.80221
# [230]	train-auc:0.82432	test-auc:0.80221
# [231]	train-auc:0.82449	test-auc:0.80238
# [232]	train-auc:0.82466	test-auc:0.80239
# [233]	train-auc:0.82474	test-auc:0.80240
# [234]	train-auc:0.82483	test-auc:0.80247
# [235]	train-auc:0.82488	test-auc:0.80251
# [236]	train-auc:0.82495	test-auc:0.80248
# [237]	train-auc:0.82506	test-auc:0.80250
# [238]	train-auc:0.82516	test-auc:0.80258
# [239]	train-auc:0.82519	test-auc:0.80256
# [240]	train-auc:0.82534	test-auc:0.80256
# [241]	train-auc:0.82540	test-auc:0.80260
# [242]	train-auc:0.82542	test-auc:0.80259
# [243]	train-auc:0.82550	test-auc:0.80251
# [244]	train-auc:0.82559	test-auc:0.80253
# [245]	train-auc:0.82571	test-auc:0.80254
# [246]	train-auc:0.82577	test-auc:0.80256
# [247]	train-auc:0.82586	test-auc:0.80258
# [248]	train-auc:0.82602	test-auc:0.80275
# [249]	train-auc:0.82608	test-auc:0.80282
# [250]	train-auc:0.82619	test-auc:0.80288
# [251]	train-auc:0.82639	test-auc:0.80297
# [252]	train-auc:0.82641	test-auc:0.80300
# [253]	train-auc:0.82659	test-auc:0.80307
# [254]	train-auc:0.82669	test-auc:0.80307
# [255]	train-auc:0.82685	test-auc:0.80307
# [256]	train-auc:0.82700	test-auc:0.80308
# [257]	train-auc:0.82702	test-auc:0.80311
# [258]	train-auc:0.82704	test-auc:0.80314
# [259]	train-auc:0.82719	test-auc:0.80314
# [260]	train-auc:0.82725	test-auc:0.80322
# [261]	train-auc:0.82740	test-auc:0.80334
# [262]	train-auc:0.82753	test-auc:0.80339
# [263]	train-auc:0.82758	test-auc:0.80340
# [264]	train-auc:0.82769	test-auc:0.80342
# [265]	train-auc:0.82785	test-auc:0.80353
# [266]	train-auc:0.82797	test-auc:0.80359
# [267]	train-auc:0.82809	test-auc:0.80357
# [268]	train-auc:0.82817	test-auc:0.80357
# [269]	train-auc:0.82818	test-auc:0.80357
# [270]	train-auc:0.82830	test-auc:0.80365
# [271]	train-auc:0.82831	test-auc:0.80363
# [272]	train-auc:0.82842	test-auc:0.80365
# [273]	train-auc:0.82853	test-auc:0.80363
# [274]	train-auc:0.82869	test-auc:0.80374
# [275]	train-auc:0.82883	test-auc:0.80375
# [276]	train-auc:0.82882	test-auc:0.80374
# [277]	train-auc:0.82888	test-auc:0.80374
# [278]	train-auc:0.82907	test-auc:0.80381
# [279]	train-auc:0.82912	test-auc:0.80377
# [280]	train-auc:0.82919	test-auc:0.80373
# [281]	train-auc:0.82928	test-auc:0.80376
# [282]	train-auc:0.82930	test-auc:0.80379
# [283]	train-auc:0.82945	test-auc:0.80384
# [284]	train-auc:0.82946	test-auc:0.80386
# [285]	train-auc:0.82952	test-auc:0.80385
# [286]	train-auc:0.82967	test-auc:0.80386
# [287]	train-auc:0.82970	test-auc:0.80385
# [288]	train-auc:0.82980	test-auc:0.80390
# [289]	train-auc:0.82994	test-auc:0.80394
# [290]	train-auc:0.83009	test-auc:0.80392
# [291]	train-auc:0.83016	test-auc:0.80385
# [292]	train-auc:0.83017	test-auc:0.80385
# [293]	train-auc:0.83027	test-auc:0.80389
# [294]	train-auc:0.83040	test-auc:0.80394
# [295]	train-auc:0.83042	test-auc:0.80396
# [296]	train-auc:0.83059	test-auc:0.80408
# [297]	train-auc:0.83071	test-auc:0.80407
# [298]	train-auc:0.83078	test-auc:0.80407
# [299]	train-auc:0.83088	test-auc:0.80408
# [300]	train-auc:0.83102	test-auc:0.80408
# [301]	train-auc:0.83113	test-auc:0.80407
# [302]	train-auc:0.83117	test-auc:0.80405
# [303]	train-auc:0.83131	test-auc:0.80406
# [304]	train-auc:0.83142	test-auc:0.80400
# [305]	train-auc:0.83150	test-auc:0.80406
# [306]	train-auc:0.83154	test-auc:0.80405
# [307]	train-auc:0.83171	test-auc:0.80418
# [308]	train-auc:0.83180	test-auc:0.80418
# [309]	train-auc:0.83193	test-auc:0.80429
# [310]	train-auc:0.83204	test-auc:0.80427
# [311]	train-auc:0.83219	test-auc:0.80444
# [312]	train-auc:0.83225	test-auc:0.80446
# [313]	train-auc:0.83237	test-auc:0.80442
# [314]	train-auc:0.83243	test-auc:0.80442
# [315]	train-auc:0.83252	test-auc:0.80445
# [316]	train-auc:0.83267	test-auc:0.80457
# [317]	train-auc:0.83276	test-auc:0.80461
# [318]	train-auc:0.83282	test-auc:0.80467
# [319]	train-auc:0.83288	test-auc:0.80463
# [320]	train-auc:0.83301	test-auc:0.80479
# [321]	train-auc:0.83308	test-auc:0.80481
# [322]	train-auc:0.83312	test-auc:0.80483
# [323]	train-auc:0.83319	test-auc:0.80479
# [324]	train-auc:0.83324	test-auc:0.80477
# [325]	train-auc:0.83337	test-auc:0.80474
# [326]	train-auc:0.83351	test-auc:0.80479
# [327]	train-auc:0.83369	test-auc:0.80481
# [328]	train-auc:0.83381	test-auc:0.80488
# [329]	train-auc:0.83389	test-auc:0.80492
# [330]	train-auc:0.83401	test-auc:0.80497
# [331]	train-auc:0.83405	test-auc:0.80501
# [332]	train-auc:0.83419	test-auc:0.80493
# [333]	train-auc:0.83427	test-auc:0.80497
# [334]	train-auc:0.83433	test-auc:0.80494
# [335]	train-auc:0.83442	test-auc:0.80500
# [336]	train-auc:0.83457	test-auc:0.80506
# [337]	train-auc:0.83473	test-auc:0.80514
# [338]	train-auc:0.83482	test-auc:0.80520
# [339]	train-auc:0.83489	test-auc:0.80521
# [340]	train-auc:0.83493	test-auc:0.80521
# [341]	train-auc:0.83503	test-auc:0.80525
# [342]	train-auc:0.83519	test-auc:0.80533
# [343]	train-auc:0.83524	test-auc:0.80536
# [344]	train-auc:0.83530	test-auc:0.80530
# [345]	train-auc:0.83546	test-auc:0.80539
# [346]	train-auc:0.83552	test-auc:0.80541
# [347]	train-auc:0.83565	test-auc:0.80542
# [348]	train-auc:0.83572	test-auc:0.80544
# [349]	train-auc:0.83586	test-auc:0.80552
# [350]	train-auc:0.83593	test-auc:0.80545
# [351]	train-auc:0.83607	test-auc:0.80552
# [352]	train-auc:0.83619	test-auc:0.80557
# [353]	train-auc:0.83627	test-auc:0.80560
# [354]	train-auc:0.83632	test-auc:0.80562
# [355]	train-auc:0.83637	test-auc:0.80565
# [356]	train-auc:0.83639	test-auc:0.80569
# [357]	train-auc:0.83645	test-auc:0.80574
# [358]	train-auc:0.83655	test-auc:0.80571
# [359]	train-auc:0.83668	test-auc:0.80573
# [360]	train-auc:0.83678	test-auc:0.80571
# [361]	train-auc:0.83691	test-auc:0.80573
# [362]	train-auc:0.83698	test-auc:0.80570
# [363]	train-auc:0.83704	test-auc:0.80567
# [364]	train-auc:0.83705	test-auc:0.80565
# [365]	train-auc:0.83713	test-auc:0.80571
# [366]	train-auc:0.83721	test-auc:0.80566
# [367]	train-auc:0.83726	test-auc:0.80569

# %%
cv_res
# Out:
# [(0.655230607823682, 0.6092168818884154, 245),
#  (0.6745235005339973, 0.6113830252776449, 357)]

# %%
gini_cv = 2 * roc_auc_score(data[col_target], data['cv_score']) - 1
print(f'Cross validation score performance: {gini_cv:.4f}')
# Out:
# Cross validation score performance: 0.6104

# %%
roc_auc_score(data[col_target], data['cv_score'])
# Out:
# 0.8051871256066337

# %%
params = {    
    'eta': 0.1,
    'max_depth': 3,
    'subsample': 0.7,
    'colsample_bytree': 0.7,

    'eval_metric': 'auc',
    'objective': 'binary:logistic' ,
    'booster': 'gbtree',
    'tree_method': 'exact',

    'seed': 12
}

evals_result = {}
booster = xgb.train(
    params = params,
    dtrain = xgb.DMatrix(data[cols_pred], data[col_target]),
    evals = (
        (xgb.DMatrix(data[cols_pred], data[col_target]), 'train'),
    ),
    num_boost_round = 130,
    evals_result = evals_result
)
# Out:
# [0]	train-auc:0.68319
# [1]	train-auc:0.72357
# [2]	train-auc:0.74129
# [3]	train-auc:0.73985
# [4]	train-auc:0.74000
# [5]	train-auc:0.73952
# [6]	train-auc:0.74883
# [7]	train-auc:0.76306
# [8]	train-auc:0.76642
# [9]	train-auc:0.76719
# [10]	train-auc:0.76662
# [11]	train-auc:0.76586
# [12]	train-auc:0.76781
# [13]	train-auc:0.77193
# [14]	train-auc:0.77365
# [15]	train-auc:0.77449
# [16]	train-auc:0.77552
# [17]	train-auc:0.77617
# [18]	train-auc:0.77730
# [19]	train-auc:0.77785
# [20]	train-auc:0.77764
# [21]	train-auc:0.77875
# [22]	train-auc:0.77916
# [23]	train-auc:0.78006
# [24]	train-auc:0.78030
# [25]	train-auc:0.78166
# [26]	train-auc:0.78196
# [27]	train-auc:0.78270
# [28]	train-auc:0.78319
# [29]	train-auc:0.78370
# [30]	train-auc:0.78443
# [31]	train-auc:0.78447
# [32]	train-auc:0.78507
# [33]	train-auc:0.78587
# [34]	train-auc:0.78686
# [35]	train-auc:0.78739
# [36]	train-auc:0.78786
# [37]	train-auc:0.78890
# [38]	train-auc:0.78924
# [39]	train-auc:0.78980
# [40]	train-auc:0.79017
# [41]	train-auc:0.79105
# [42]	train-auc:0.79139
# [43]	train-auc:0.79218
# [44]	train-auc:0.79300
# [45]	train-auc:0.79281
# [46]	train-auc:0.79332
# [47]	train-auc:0.79328
# [48]	train-auc:0.79351
# [49]	train-auc:0.79362
# [50]	train-auc:0.79407
# [51]	train-auc:0.79438
# [52]	train-auc:0.79445
# [53]	train-auc:0.79481
# [54]	train-auc:0.79521
# [55]	train-auc:0.79540
# [56]	train-auc:0.79553
# [57]	train-auc:0.79578
# [58]	train-auc:0.79642
# [59]	train-auc:0.79666
# [60]	train-auc:0.79676
# [61]	train-auc:0.79709
# [62]	train-auc:0.79732
# [63]	train-auc:0.79776
# [64]	train-auc:0.79787
# [65]	train-auc:0.79803
# [66]	train-auc:0.79839
# [67]	train-auc:0.79842
# [68]	train-auc:0.79839
# [69]	train-auc:0.79841
# [70]	train-auc:0.79880
# [71]	train-auc:0.79877
# [72]	train-auc:0.79889
# [73]	train-auc:0.79908
# [74]	train-auc:0.79923
# [75]	train-auc:0.79949
# [76]	train-auc:0.79961
# [77]	train-auc:0.79975
# [78]	train-auc:0.79980
# [79]	train-auc:0.79988
# [80]	train-auc:0.79994
# [81]	train-auc:0.80015
# [82]	train-auc:0.80062
# [83]	train-auc:0.80074
# [84]	train-auc:0.80111
# [85]	train-auc:0.80118
# [86]	train-auc:0.80127
# [87]	train-auc:0.80150
# [88]	train-auc:0.80170
# [89]	train-auc:0.80177
# [90]	train-auc:0.80206
# [91]	train-auc:0.80238
# [92]	train-auc:0.80257
# [93]	train-auc:0.80259
# [94]	train-auc:0.80263
# [95]	train-auc:0.80265
# [96]	train-auc:0.80276
# [97]	train-auc:0.80281
# [98]	train-auc:0.80307
# [99]	train-auc:0.80317
# [100]	train-auc:0.80333
# [101]	train-auc:0.80339
# [102]	train-auc:0.80352
# [103]	train-auc:0.80354
# [104]	train-auc:0.80362
# [105]	train-auc:0.80372
# [106]	train-auc:0.80377
# [107]	train-auc:0.80377
# [108]	train-auc:0.80399
# [109]	train-auc:0.80441
# [110]	train-auc:0.80445
# [111]	train-auc:0.80464
# [112]	train-auc:0.80476
# [113]	train-auc:0.80495
# [114]	train-auc:0.80502
# [115]	train-auc:0.80524
# [116]	train-auc:0.80552
# [117]	train-auc:0.80567
# [118]	train-auc:0.80573
# [119]	train-auc:0.80584
# [120]	train-auc:0.80597
# [121]	train-auc:0.80602
# [122]	train-auc:0.80606
# [123]	train-auc:0.80610
# [124]	train-auc:0.80617
# [125]	train-auc:0.80620
# [126]	train-auc:0.80624
# [127]	train-auc:0.80625
# [128]	train-auc:0.80642
# [129]	train-auc:0.80646
