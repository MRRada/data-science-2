# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pickle
from tqdm.notebook import tqdm
from pathlib import Path
import xgboost as xgb

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from xgboost import plot_importance

# %% [markdown]
# # Načítání dat

# %%
data = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_train.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')
data_test = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_test.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')

# %%
# set width of Jupyter notebook
from IPython.core.display import HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

# set some visual properties of displaying pandas DataFrame
pd.options.display.max_columns=200
pd.options.display.max_rows=200
# Out:
# <style>.container { width:70% !important; }</style>

# %%
data
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0
# ...                            ...             ...
# INN16851                       2.0             0.0
# INN06266                       NaN             1.0
# INN11285                       1.0             0.0
# INN00861                       0.0             1.0
# INN15796                       NaN             0.0
#
# [32647 rows x 18 columns]

# %% [markdown]
# # Overview of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32647 entries, INN10204 to INN15796
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          28231 non-null  float64
#  1   no_of_children                        5043 non-null   float64
#  2   no_of_weekend_nights                  7729 non-null   float64
#  3   no_of_week_nights                     24287 non-null  float64
#  4   type_of_meal_plan                     16544 non-null  object
#  5   required_car_parking_space            17863 non-null  float64
#  6   room_type_reserved                    11360 non-null  object
#  7   lead_time                             6935 non-null   float64
#  8   arrival_year                          29654 non-null  float64
#  9   arrival_month                         31740 non-null  float64
#  10  arrival_date                          5457 non-null   float64
#  11  market_segment_type                   18526 non-null  object
#  12  repeated_guest                        7669 non-null   float64
#  13  no_of_previous_cancellations          32578 non-null  float64
#  14  no_of_previous_bookings_not_canceled  18026 non-null  float64
#  15  avg_price_per_room                    9058 non-null   float64
#  16  no_of_special_requests                25197 non-null  float64
#  17  booking_status                        32295 non-null  float64
# dtypes: float64(15), object(3)
# memory usage: 4.7+ MB

# %%
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18

# %%
data.rename(columns = {'booking_status':'TARGET'}, inplace = True)
data_test.rename(columns = {'booking_status':'TARGET'}, inplace = True)
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0

# %%
col_target = "TARGET"
col_month = "arrival_month"

# %%
# define list of predictors
cols_pred = list(data.columns[0:-1])

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# required_car_parking_space              float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# repeated_guest                          float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan      object
# room_type_reserved     object
# market_segment_type    object
# dtype: object

# %%
len(cols_pred),cols_pred
# Out:
# (17,
#  ['no_of_adults',
#   'no_of_children',
#   'no_of_weekend_nights',
#   'no_of_week_nights',
#   'type_of_meal_plan',
#   'required_car_parking_space',
#   'room_type_reserved',
#   'lead_time',
#   'arrival_year',
#   'arrival_month',
#   'arrival_date',
#   'market_segment_type',
#   'repeated_guest',
#   'no_of_previous_cancellations',
#   'no_of_previous_bookings_not_canceled',
#   'avg_price_per_room',
#   'no_of_special_requests'])

# %%
data.TARGET.value_counts(dropna=False)
# Out:
# TARGET
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %%
data = data.dropna(subset=["TARGET"])

# %%
data.drop(data.loc[:,list((100*(data.isnull().sum()/len(data.index))>98))].columns)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0
# ...                            ...     ...
# INN16851                       2.0     0.0
# INN06266                       NaN     1.0
# INN11285                       1.0     0.0
# INN00861                       0.0     1.0
# INN15796                       NaN     0.0
#
# [32295 rows x 18 columns]

# %%
data['sample'] = 'default'
data_test['sample'] = 'default'
# use train_test_split to split the intime into train and rest (don't forget seed)
data_train, data_valid = train_test_split(data, test_size=0.4, random_state = 12)
data.loc[data_train.index, 'sample'] = 'train'
data.loc[data_valid.index, 'sample'] = 'valid'
data_test.loc[data_test.index, 'sample'] = "test"

# %%
def default_rate_in_time_per_sample(dt, col_target, col_month, col_sample):
    # group by over month and sample
    dt_grp = dt.groupby([col_month, col_sample]).agg(
        def_rt = (col_target, 'mean')
    ).reset_index()
    
    # pivot sample values to columns
    dt_grp_pivot = dt_grp.pivot(index = col_month, columns = col_sample, values = 'def_rt')

    # plot default rate in time
    lines = plt.plot(range(len(dt_grp_pivot)), dt_grp_pivot, marker = 'o')
    plt.xticks(range(len(dt_grp_pivot)), dt_grp_pivot.index, rotation = 90)
    # set legend
    plt.legend(iter(lines), tuple(dt_grp_pivot.columns), loc='best', bbox_to_anchor=(1.05, 1))
    
    plt.ylim([0, 1])
    plt.ylabel('default rate', loc='top')
    plt.xlabel('month', loc='right')
    
    ax = plt.gca()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('gray')
    ax.spines['bottom'].set_color('gray')
    ax.tick_params(axis='y', colors='gray')
    ax.tick_params(axis='x', colors='gray') 
    
    plt.show()

# %% [markdown]
# # Plotting the cancellations per month

# %%
default_rate_in_time_per_sample(data, col_target, col_month, 'sample')

# %%
train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid')

# %%
# find columns with infinity values
cols_with_inf = []
for col in cols_pred_num:
    if np.any(np.isinf(data[col])):
        cols_with_inf.append(col)
        print(f'Column {col} includes infinity values.')

# find columns with negative infinity values
cols_with_neginf = []
for col in cols_pred_num:
    if np.any(np.isneginf(data[col])):
        cols_with_neginf.append(col)
        print(f'Column {col} includes negative infinity values.')

# %%
# replace infinity values
for col in cols_with_inf:
    data[col] = data[col].replace(np.inf, 9999999)

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_dr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_dr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_dr'] + alpha * total_dr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
total_dr = np.mean(data[train_mask][col_target])
MTEdummies={}

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )
        MTEdummies[pred] = new_vals
        
        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_dr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type']

# %%
#total_dr = np.mean(data_test[train_mask][col_target])

# encode categorical predictors
for pred in tqdm(cols_pred_cat):
    if len(data_test[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data_test[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data_test[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data_test.columns:
                del data_test[d]
                
        data_test = data_test.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = MTEdummies[pred]

        additional_values = set(data_test[data_test[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_dr

        data_test['MTE_' + pred] = data_test[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# set best parameters to be used in XGBoost
params = {    
    'max_depth': 4,
    
    'objective': 'binary:logistic',
    'eval_metric': ['auc'],
}

evals_result = {}
booster = xgb.train(
    params = params,
    dtrain = xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]),
    num_boost_round = 1000,
    evals = (
        (xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]), 'train'),
        (xgb.DMatrix(data[valid_mask][cols_pred], data[valid_mask][col_target]), 'valid'),        
    ),
    evals_result = evals_result,
    early_stopping_rounds = 10
)
# Out:
# [0]	train-auc:0.70896	valid-auc:0.70666
# [1]	train-auc:0.74298	valid-auc:0.73913
# [2]	train-auc:0.75825	valid-auc:0.75660
# [3]	train-auc:0.76795	valid-auc:0.76683
# [4]	train-auc:0.77516	valid-auc:0.77289
# [5]	train-auc:0.78349	valid-auc:0.78164
# [6]	train-auc:0.78574	valid-auc:0.78362
# [7]	train-auc:0.78985	valid-auc:0.78722
# [8]	train-auc:0.79269	valid-auc:0.78954
# [9]	train-auc:0.79447	valid-auc:0.79138
# [10]	train-auc:0.79750	valid-auc:0.79345
# [11]	train-auc:0.79762	valid-auc:0.79380
# [12]	train-auc:0.79944	valid-auc:0.79517
# [13]	train-auc:0.80143	valid-auc:0.79654
# [14]	train-auc:0.80237	valid-auc:0.79753
# [15]	train-auc:0.80329	valid-auc:0.79813
# [16]	train-auc:0.80405	valid-auc:0.79842
# [17]	train-auc:0.80519	valid-auc:0.79908
# [18]	train-auc:0.80538	valid-auc:0.79932
# [19]	train-auc:0.80579	valid-auc:0.79955
# [20]	train-auc:0.80629	valid-auc:0.80003
# [21]	train-auc:0.80796	valid-auc:0.80159
# [22]	train-auc:0.80823	valid-auc:0.80176
# [23]	train-auc:0.80872	valid-auc:0.80199
# [24]	train-auc:0.80898	valid-auc:0.80190
# [25]	train-auc:0.81073	valid-auc:0.80291
# [26]	train-auc:0.81230	valid-auc:0.80394
# [27]	train-auc:0.81230	valid-auc:0.80399
# [28]	train-auc:0.81391	valid-auc:0.80478
# [29]	train-auc:0.81527	valid-auc:0.80507
# [30]	train-auc:0.81543	valid-auc:0.80515
# [31]	train-auc:0.81580	valid-auc:0.80534
# [32]	train-auc:0.81623	valid-auc:0.80561
# [33]	train-auc:0.81677	valid-auc:0.80581
# [34]	train-auc:0.81755	valid-auc:0.80585
# [35]	train-auc:0.81775	valid-auc:0.80621
# [36]	train-auc:0.81820	valid-auc:0.80643
# [37]	train-auc:0.81891	valid-auc:0.80646
# [38]	train-auc:0.81936	valid-auc:0.80668
# [39]	train-auc:0.82055	valid-auc:0.80695
# [40]	train-auc:0.82122	valid-auc:0.80747
# [41]	train-auc:0.82126	valid-auc:0.80751
# [42]	train-auc:0.82181	valid-auc:0.80745
# [43]	train-auc:0.82199	valid-auc:0.80748
# [44]	train-auc:0.82294	valid-auc:0.80846
# [45]	train-auc:0.82389	valid-auc:0.80881
# [46]	train-auc:0.82496	valid-auc:0.80854
# [47]	train-auc:0.82549	valid-auc:0.80894
# [48]	train-auc:0.82557	valid-auc:0.80896
# [49]	train-auc:0.82583	valid-auc:0.80905
# [50]	train-auc:0.82641	valid-auc:0.80947
# [51]	train-auc:0.82660	valid-auc:0.80956
# [52]	train-auc:0.82675	valid-auc:0.80964
# [53]	train-auc:0.82684	valid-auc:0.80964
# [54]	train-auc:0.82707	valid-auc:0.80979
# [55]	train-auc:0.82729	valid-auc:0.80990
# [56]	train-auc:0.82752	valid-auc:0.80998
# [57]	train-auc:0.82860	valid-auc:0.80988
# [58]	train-auc:0.82884	valid-auc:0.80996
# [59]	train-auc:0.82918	valid-auc:0.81009
# [60]	train-auc:0.82947	valid-auc:0.81021
# [61]	train-auc:0.82998	valid-auc:0.81022
# [62]	train-auc:0.83067	valid-auc:0.81008
# [63]	train-auc:0.83061	valid-auc:0.81007
# [64]	train-auc:0.83140	valid-auc:0.81034
# [65]	train-auc:0.83209	valid-auc:0.81031
# [66]	train-auc:0.83226	valid-auc:0.81036
# [67]	train-auc:0.83241	valid-auc:0.81039
# [68]	train-auc:0.83289	valid-auc:0.81026
# [69]	train-auc:0.83369	valid-auc:0.81028
# [70]	train-auc:0.83414	valid-auc:0.81031
# [71]	train-auc:0.83436	valid-auc:0.81032
# [72]	train-auc:0.83446	valid-auc:0.81034
# [73]	train-auc:0.83457	valid-auc:0.81035
# [74]	train-auc:0.83479	valid-auc:0.81042
# [75]	train-auc:0.83514	valid-auc:0.81054
# [76]	train-auc:0.83543	valid-auc:0.81051
# [77]	train-auc:0.83558	valid-auc:0.81055
# [78]	train-auc:0.83561	valid-auc:0.81054
# [79]	train-auc:0.83583	valid-auc:0.81055
# [80]	train-auc:0.83650	valid-auc:0.81067
# [81]	train-auc:0.83704	valid-auc:0.81058
# [82]	train-auc:0.83782	valid-auc:0.81083
# [83]	train-auc:0.83848	valid-auc:0.81095
# [84]	train-auc:0.83915	valid-auc:0.81094
# [85]	train-auc:0.84009	valid-auc:0.81113
# [86]	train-auc:0.84035	valid-auc:0.81107
# [87]	train-auc:0.84108	valid-auc:0.81094
# [88]	train-auc:0.84160	valid-auc:0.81099
# [89]	train-auc:0.84165	valid-auc:0.81098
# [90]	train-auc:0.84171	valid-auc:0.81098
# [91]	train-auc:0.84215	valid-auc:0.81089
# [92]	train-auc:0.84245	valid-auc:0.81099
# [93]	train-auc:0.84306	valid-auc:0.81116
# [94]	train-auc:0.84328	valid-auc:0.81123
# [95]	train-auc:0.84352	valid-auc:0.81112
# [96]	train-auc:0.84376	valid-auc:0.81109
# [97]	train-auc:0.84404	valid-auc:0.81132
# [98]	train-auc:0.84425	valid-auc:0.81142
# [99]	train-auc:0.84470	valid-auc:0.81139
# [100]	train-auc:0.84478	valid-auc:0.81143
# [101]	train-auc:0.84552	valid-auc:0.81161
# [102]	train-auc:0.84587	valid-auc:0.81154
# [103]	train-auc:0.84650	valid-auc:0.81153
# [104]	train-auc:0.84710	valid-auc:0.81154
# [105]	train-auc:0.84737	valid-auc:0.81155
# [106]	train-auc:0.84756	valid-auc:0.81166
# [107]	train-auc:0.84761	valid-auc:0.81174
# [108]	train-auc:0.84802	valid-auc:0.81196
# [109]	train-auc:0.84850	valid-auc:0.81213
# [110]	train-auc:0.84869	valid-auc:0.81224
# [111]	train-auc:0.84904	valid-auc:0.81209
# [112]	train-auc:0.84911	valid-auc:0.81208
# [113]	train-auc:0.84964	valid-auc:0.81194
# [114]	train-auc:0.84979	valid-auc:0.81186
# [115]	train-auc:0.84992	valid-auc:0.81182
# [116]	train-auc:0.85078	valid-auc:0.81209
# [117]	train-auc:0.85143	valid-auc:0.81216
# [118]	train-auc:0.85202	valid-auc:0.81205
# [119]	train-auc:0.85235	valid-auc:0.81203

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster.best_score
best_iteration = booster.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in booster.get_score(importance_type = importance_type).items()], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = 16
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:20])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:20])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# # Tento

# %%
#Removing least important predictor)
cols_pred.remove("no_of_children")
cols_pred.remove("arrival_date")
cols_pred
#Tenhle další už je horší, takže ho používat nebudeme
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32295 entries, INN10204 to INN15796
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          27911 non-null  float64
#  1   no_of_children                        4988 non-null   float64
#  2   no_of_weekend_nights                  7650 non-null   float64
#  3   no_of_week_nights                     24019 non-null  float64
#  4   type_of_meal_plan                     16365 non-null  object
#  5   required_car_parking_space            17674 non-null  float64
#  6   room_type_reserved                    11244 non-null  object
#  7   lead_time                             6852 non-null   float64
#  8   arrival_year                          29330 non-null  float64
#  9   arrival_month                         31399 non-null  float64
#  10  arrival_date                          5392 non-null   float64
#  11  market_segment_type                   18334 non-null  object
#  12  repeated_guest                        7580 non-null   float64
#  13  no_of_previous_cancellations          32226 non-null  float64
#  14  no_of_previous_bookings_not_canceled  17830 non-null  float64
#  15  avg_price_per_room                    8966 non-null   float64
#  16  no_of_special_requests                24932 non-null  float64
#  17  TARGET                                32295 non-null  float64
#  18  sample                                32295 non-null  object
#  19  MTE_type_of_meal_plan                 16365 non-null  float64
#  20  MTE_room_type_reserved                11244 non-null  float64
#  21  MTE_market_segment_type               18334 non-null  float64
# dtypes: float64(18), object(4)
# memory usage: 6.7+ MB

# %%
#Nevsimat si

#mean_lead_time=data[train_mask].loc[data[train_mask]['lead_time'].between(0,180), 'lead_time'].mean(skipna=True)
#mean_lead_time

# %%
mean_avg_price_per_room=data[train_mask].avg_price_per_room.mean(skipna=True)
mean_avg_price_per_room
# Out:
# 103.80021914216145

# %%
rep=data[train_mask].copy().avg_price_per_room.fillna(value=mean_avg_price_per_room)
rep=rep.tolist()
help=data[train_mask].copy()
help['avg_price_per_room'] = rep
data[train_mask] = help

# %%
data[train_mask].avg_price_per_room.value_counts(dropna=False)
# Out:
# avg_price_per_room
# 103.800219    14038
# 65.000000       134
# 75.000000       116
# 90.000000       112
# 115.000000      101
#               ...
# 125.120000        1
# 92.350000         1
# 95.580000         1
# 108.290000        1
# 73.810000         1
# Name: count, Length: 1339, dtype: int64

# %%
mean_avg_price_per_room_test=data_test.avg_price_per_room.mean(skipna=True)
mean_avg_price_per_room_test
# Out:
# 103.37065913370998

# %%
#taktiez pre testovaci set
data_test['avg_price_per_room'] = data_test.avg_price_per_room.fillna(value=mean_avg_price_per_room_test)

# %%
data_test.avg_price_per_room.value_counts(dropna=False)
# Out:
# avg_price_per_room
# 103.370659    2531
# 115.000000      25
# 95.000000       24
# 65.000000       23
# 120.000000      22
#               ...
# 80.100000        1
# 251.500000       1
# 86.320000        1
# 40.670000        1
# 87.540000        1
# Name: count, Length: 427, dtype: int64

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=12,
    max_depth=5,
    eval_metric=['auc'],
    gamma=0.3,
    verbosity=1,
    use_label_encoder=False,
    early_stopping_rounds=12,
    eta=0.2
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.73250	validation_1-auc:0.73033
# [1]	validation_0-auc:0.76157	validation_1-auc:0.75524
# [2]	validation_0-auc:0.76914	validation_1-auc:0.76411
# [3]	validation_0-auc:0.77544	validation_1-auc:0.76965
# [4]	validation_0-auc:0.78034	validation_1-auc:0.77505
# [5]	validation_0-auc:0.78490	validation_1-auc:0.77589
# [6]	validation_0-auc:0.78776	validation_1-auc:0.77911
# [7]	validation_0-auc:0.79142	validation_1-auc:0.78161
# [8]	validation_0-auc:0.79563	validation_1-auc:0.78547
# [9]	validation_0-auc:0.79905	validation_1-auc:0.78487
# [10]	validation_0-auc:0.80014	validation_1-auc:0.78685
# [11]	validation_0-auc:0.80285	validation_1-auc:0.78951
# [12]	validation_0-auc:0.80430	validation_1-auc:0.79042
# [13]	validation_0-auc:0.80471	validation_1-auc:0.79068
# [14]	validation_0-auc:0.80582	validation_1-auc:0.79160
# [15]	validation_0-auc:0.80703	validation_1-auc:0.79307
# [16]	validation_0-auc:0.80864	validation_1-auc:0.79383
# [17]	validation_0-auc:0.80953	validation_1-auc:0.79471
# [18]	validation_0-auc:0.81022	validation_1-auc:0.79490
# [19]	validation_0-auc:0.81053	validation_1-auc:0.79534
# [20]	validation_0-auc:0.81130	validation_1-auc:0.79321
# [21]	validation_0-auc:0.81373	validation_1-auc:0.79236
# [22]	validation_0-auc:0.81517	validation_1-auc:0.79354
# [23]	validation_0-auc:0.81533	validation_1-auc:0.79358
# [24]	validation_0-auc:0.81570	validation_1-auc:0.79413
# [25]	validation_0-auc:0.81596	validation_1-auc:0.79461
# [26]	validation_0-auc:0.81643	validation_1-auc:0.79264
# [27]	validation_0-auc:0.81690	validation_1-auc:0.79280
# [28]	validation_0-auc:0.81852	validation_1-auc:0.79363
# [29]	validation_0-auc:0.81916	validation_1-auc:0.79298
# [30]	validation_0-auc:0.81942	validation_1-auc:0.79337
# [31]	validation_0-auc:0.82058	validation_1-auc:0.78840
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=12,
#               enable_categorical=False, eta=0.2, eval_metric=['auc'],
#               feature_types=None, gamma=0.3, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
importance_type = 'total_gain'

orig_feature_names = cols_pred
booster_sklearn.get_booster().feature_names = orig_feature_names

predictor_strength = sorted([(k, v) for k,v in booster_sklearn.get_booster().get_score(importance_type = importance_type).items()], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = len(cols_pred)

plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:20])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:20])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type']

# %% [markdown]
# # potialto

# %%
def marginal_dependence(data, predictor, bins, col_target):
    dt = data.copy()
    dt[predictor + 'bin'] = pd.qcut(dt.rank(method='first')[predictor], bins).copy() #pd.qcut(df.rank(method='first'), nbins)
    dt.groupby(predictor + 'bin', observed=False).agg(
        def_prob=(col_target, np.mean)
    ).plot(figsize=(9, 6))

# %%
marginal_dependence(data[train_mask], 'no_of_weekend_nights', 10, col_target)
# Out:
# C:\Users\matej\AppData\Local\Temp\ipykernel_48484\3003329733.py:4: FutureWarning: The provided callable <function mean at 0x000001AE6ABCE7A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   dt.groupby(predictor + 'bin', observed=False).agg(

# %%
data_test['predicted_pd'] = booster_sklearn.get_booster().predict(xgb.DMatrix(data_test[cols_pred]), iteration_range=(0,booster_sklearn.best_iteration))
data_test['predicted_score'] = np.log(data_test['predicted_pd'] / (1 - data_test['predicted_pd']))

# %%
def plot_score_calibration(dt, col_score, col_target, n_bins = 25):
    min_score = dt[col_score].min() - 0.1
    max_score = dt[col_score].max() + 0.1
    
    bins = [round(min_score + i * (max_score - min_score) / n_bins, 2) for i in range(n_bins+1)]
    dt = dt.assign(score_bin = pd.cut(dt[col_score], bins = bins, include_lowest = False))
    
    dt_grp = dt.groupby('score_bin', observed=False).agg(
        bad_cnt = (col_target, 'sum'),
        tot_cnt = (col_target, len),
        def_rt = (col_target, 'mean'),
        avg_score = (col_score, 'mean')
    )
    dt_grp['good_cnt'] = dt_grp['tot_cnt'] - dt_grp['bad_cnt']
    dt_grp['bad_cnt_norm'] = dt_grp['bad_cnt'] / dt_grp['tot_cnt']
    dt_grp['good_cnt_norm'] = dt_grp['good_cnt'] / dt_grp['tot_cnt']
    dt_grp['expected_pd'] = 1 / (1 + np.exp(-dt_grp['avg_score']))
    
    fig, axs = plt.subplots(1,2, figsize = (12,4))
    fig.suptitle(col_score)
    plt.subplots_adjust(wspace = 0.4)
    axs[0].bar(range(len(dt_grp)), dt_grp['bad_cnt'], color = 'salmon', label = 'bads')
    axs[0].bar(range(len(dt_grp)), dt_grp['good_cnt'], bottom = dt_grp['bad_cnt'], color = 'lightblue', label = 'goods')
    axs[0].set_ylabel('observations count')
    axs[0].set_xlabel('score')
    axs[0].set_xticks(range(len(dt_grp)))
    axs[0].set_xticklabels(dt_grp.index, rotation = 90)
    
    axs[0].spines['right'].set_color('gray')
    axs[0].spines['top'].set_visible(False)
    axs[0].spines['left'].set_color('gray')
    axs[0].spines['bottom'].set_color('gray')
    axs[0].tick_params(axis='y', colors='gray')
    axs[0].tick_params(axis='x', colors='gray')
    
    ax0l = axs[0].twinx()
    ax0l.plot(range(len(dt_grp)), dt_grp['def_rt'], marker = 'o', color = 'red')
    ax0l.plot(range(len(dt_grp)), dt_grp['expected_pd'], color = 'black', ls = '--')
    ax0l.set_ylabel('default rate', color = 'red')
    
    ax0l.spines['right'].set_color('gray')
    ax0l.spines['top'].set_visible(False)
    ax0l.spines['left'].set_color('gray')
    ax0l.spines['bottom'].set_color('gray')
    ax0l.tick_params(axis='y', colors='gray')
    ax0l.tick_params(axis='x', colors='gray')
    
    axs[1].bar(range(len(dt_grp)), dt_grp['bad_cnt_norm'], color = 'salmon', label = 'bads')
    axs[1].bar(range(len(dt_grp)), dt_grp['good_cnt_norm'], bottom = dt_grp['bad_cnt_norm'], color = 'lightblue', label = 'goods')
    axs[1].set_ylabel('frequency')
    axs[1].set_xlabel('score')
    axs[1].set_xticks(range(len(dt_grp)))
    axs[1].set_xticklabels(dt_grp.index, rotation = 90)
    
    axs[1].spines['right'].set_visible(False)
    axs[1].spines['top'].set_visible(False)
    axs[1].spines['left'].set_color('gray')
    axs[1].spines['bottom'].set_color('gray')
    axs[1].tick_params(axis='y', colors='gray')
    axs[1].tick_params(axis='x', colors='gray')

# %%
plot_score_calibration(data_test, 'predicted_score', 'predicted_pd')

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin' #treba nastavit svoj priecinok kde je nainstalovany graphviz...dolezity je potom bin

from xgboost import plot_tree
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,50

plot_tree(booster, num_trees = 0)
plt.show()

rcParams['figure.figsize'] = 5,5

# %%
data_test['predicted_pd']
# Out:
# Booking_ID
# INN04969    0.048808
# INN34541    0.218451
# INN36109    0.206210
# INN01554    0.673587
# INN24975    0.180025
#               ...
# INN29523    0.105931
# INN25061    0.407966
# INN08475    0.738741
# INN13558    0.141438
# INN00626    0.171398
# Name: predicted_pd, Length: 3593, dtype: float32

# %%
data_test['booking_status']=data_test['predicted_pd']

# %%
data_test
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
# ...                  ...             ...                   ...
# INN29523             1.0             NaN                   NaN
# INN25061             2.0             NaN                   1.0
# INN08475             2.0             NaN                   NaN
# INN13558             1.0             NaN                   NaN
# INN00626             2.0             NaN                   0.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                         NaN
# INN34541                  2.0       Meal Plan 1                         0.0
# INN36109                  2.0       Meal Plan 1                         0.0
# INN01554                  3.0               NaN                         0.0
# INN24975                  NaN               NaN                         0.0
# ...                       ...               ...                         ...
# INN29523                  2.0       Meal Plan 2                         0.0
# INN25061                  NaN      Not Selected                         0.0
# INN08475                  NaN               NaN                         NaN
# INN13558                  0.0       Meal Plan 1                         NaN
# INN00626                  4.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
# ...                       ...        ...           ...            ...
# INN29523          Room_Type 1       39.0        2017.0            8.0
# INN25061                  NaN        NaN        2018.0            6.0
# INN08475                  NaN      308.0        2018.0           11.0
# INN13558                  NaN        NaN        2018.0            7.0
# INN00626          Room_Type 4        NaN        2017.0           10.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN             NaN
# INN34541             NaN             Offline             NaN
# INN36109             NaN                 NaN             NaN
# INN01554            21.0              Online             NaN
# INN24975             NaN                 NaN             NaN
# ...                  ...                 ...             ...
# INN29523             NaN             Offline             NaN
# INN25061             NaN              Online             0.0
# INN08475             NaN              Online             NaN
# INN13558            24.0                 NaN             NaN
# INN00626             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
# ...                                  ...
# INN29523                             0.0
# INN25061                             0.0
# INN08475                             0.0
# INN13558                             3.0
# INN00626                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN          103.370659
# INN34541                                     0.0          103.370659
# INN36109                                     NaN          103.370659
# INN01554                                     0.0          103.370659
# INN24975                                     NaN          103.370659
# ...                                          ...                 ...
# INN29523                                     NaN           87.000000
# INN25061                                     NaN          103.370659
# INN08475                                     0.0           78.300000
# INN13558                                    39.0          103.370659
# INN00626                                     0.0           87.540000
#
#             no_of_special_requests sample  MTE_type_of_meal_plan  \
# Booking_ID
# INN04969                       3.0   test               0.314747
# INN34541                       NaN   test               0.314747
# INN36109                       NaN   test               0.314747
# INN01554                       0.0   test                    NaN
# INN24975                       2.0   test                    NaN
# ...                            ...    ...                    ...
# INN29523                       NaN   test               0.429450
# INN25061                       NaN   test               0.328849
# INN08475                       NaN   test                    NaN
# INN13558                       0.0   test               0.314747
# INN00626                       NaN   test                    NaN
#
#             MTE_room_type_reserved  MTE_market_segment_type  predicted_pd  \
# Booking_ID
# INN04969                       NaN                      NaN      0.048808
# INN34541                       NaN                 0.304221      0.218451
# INN36109                       NaN                      NaN      0.206210
# INN01554                       NaN                 0.363562      0.673587
# INN24975                       NaN                      NaN      0.180025
# ...                            ...                      ...           ...
# INN29523                  0.323375                 0.304221      0.105931
# INN25061                       NaN                 0.363562      0.407966
# INN08475                       NaN                 0.363562      0.738741
# INN13558                       NaN                      NaN      0.141438
# INN00626                  0.346501                      NaN      0.171398
#
#             predicted_score  prediction  booking_status
# Booking_ID
# INN04969          -2.969817    0.048808        0.048808
# INN34541          -1.274714    0.218451        0.218451
# INN36109          -1.347924    0.206210        0.206210
# INN01554           0.724455    0.673587        0.673587
# INN24975          -1.516176    0.180025        0.180025
# ...                     ...         ...             ...
# INN29523          -2.132993    0.105931        0.105931
# INN25061          -0.372382    0.407966        0.407966
# INN08475           1.039433    0.738741        0.738741
# INN13558          -1.803399    0.141438        0.141438
# INN00626          -1.575755    0.171398        0.171398
#
# [3593 rows x 25 columns]

# %%
data_test['booking_status'].to_csv('eval.csv')
