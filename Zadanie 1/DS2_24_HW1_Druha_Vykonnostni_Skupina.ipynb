# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import pickle
from tqdm.notebook import tqdm
from pathlib import Path
import xgboost as xgb

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from xgboost import plot_importance

# %% [markdown]
# # Načítání dat

# %%
#Umístil jsem složku do Data ze cvičení, načítám pomocí Path
data_file_hw = Path("../Data/2024_DS2_HW1_data_train.csv")
data= pd.read_csv(data_file_hw, sep = ',', decimal = '.', index_col = 'Booking_ID')
data_file_hw2 = Path("../Data/2024_DS2_HW1_data_test.csv")
test=pd.read_csv(data_file_hw2, sep = ',', decimal = '.', index_col = 'Booking_ID')
#data = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_train.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')
#test = pd.read_csv("C:/Users/matej/Desktop/MFF UK/8. semester/Data Science 2/Zadanie 1/2024_DS2_HW1_data_test.csv", sep = ',', decimal = '.', index_col = 'Booking_ID')

# %%
# set width of Jupyter notebook
from IPython.core.display import HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

# set some visual properties of displaying pandas DataFrame
pd.options.display.max_columns=200
pd.options.display.max_rows=200
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# # Overview of the data

# %%
data
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  booking_status
# Booking_ID
# INN10204                       1.0             0.0
# INN20020                       NaN             0.0
# INN16435                       1.0             0.0
# INN07143                       2.0             0.0
# INN20511                       NaN             1.0
# ...                            ...             ...
# INN16851                       2.0             0.0
# INN06266                       NaN             1.0
# INN11285                       1.0             0.0
# INN00861                       0.0             1.0
# INN15796                       NaN             0.0
#
# [32647 rows x 18 columns]

# %%
test
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
# ...                  ...             ...                   ...
# INN29523             1.0             NaN                   NaN
# INN25061             2.0             NaN                   1.0
# INN08475             2.0             NaN                   NaN
# INN13558             1.0             NaN                   NaN
# INN00626             2.0             NaN                   0.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                         NaN
# INN34541                  2.0       Meal Plan 1                         0.0
# INN36109                  2.0       Meal Plan 1                         0.0
# INN01554                  3.0               NaN                         0.0
# INN24975                  NaN               NaN                         0.0
# ...                       ...               ...                         ...
# INN29523                  2.0       Meal Plan 2                         0.0
# INN25061                  NaN      Not Selected                         0.0
# INN08475                  NaN               NaN                         NaN
# INN13558                  0.0       Meal Plan 1                         NaN
# INN00626                  4.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
# ...                       ...        ...           ...            ...
# INN29523          Room_Type 1       39.0        2017.0            8.0
# INN25061                  NaN        NaN        2018.0            6.0
# INN08475                  NaN      308.0        2018.0           11.0
# INN13558                  NaN        NaN        2018.0            7.0
# INN00626          Room_Type 4        NaN        2017.0           10.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN             NaN
# INN34541             NaN             Offline             NaN
# INN36109             NaN                 NaN             NaN
# INN01554            21.0              Online             NaN
# INN24975             NaN                 NaN             NaN
# ...                  ...                 ...             ...
# INN29523             NaN             Offline             NaN
# INN25061             NaN              Online             0.0
# INN08475             NaN              Online             NaN
# INN13558            24.0                 NaN             NaN
# INN00626             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
# ...                                  ...
# INN29523                             0.0
# INN25061                             0.0
# INN08475                             0.0
# INN13558                             3.0
# INN00626                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN                 NaN
# INN34541                                     0.0                 NaN
# INN36109                                     NaN                 NaN
# INN01554                                     0.0                 NaN
# INN24975                                     NaN                 NaN
# ...                                          ...                 ...
# INN29523                                     NaN               87.00
# INN25061                                     NaN                 NaN
# INN08475                                     0.0               78.30
# INN13558                                    39.0                 NaN
# INN00626                                     0.0               87.54
#
#             no_of_special_requests
# Booking_ID
# INN04969                       3.0
# INN34541                       NaN
# INN36109                       NaN
# INN01554                       0.0
# INN24975                       2.0
# ...                            ...
# INN29523                       NaN
# INN25061                       NaN
# INN08475                       NaN
# INN13558                       0.0
# INN00626                       NaN
#
# [3593 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32647 entries, INN10204 to INN15796
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          28231 non-null  float64
#  1   no_of_children                        5043 non-null   float64
#  2   no_of_weekend_nights                  7729 non-null   float64
#  3   no_of_week_nights                     24287 non-null  float64
#  4   type_of_meal_plan                     16544 non-null  object
#  5   required_car_parking_space            17863 non-null  float64
#  6   room_type_reserved                    11360 non-null  object
#  7   lead_time                             6935 non-null   float64
#  8   arrival_year                          29654 non-null  float64
#  9   arrival_month                         31740 non-null  float64
#  10  arrival_date                          5457 non-null   float64
#  11  market_segment_type                   18526 non-null  object
#  12  repeated_guest                        7669 non-null   float64
#  13  no_of_previous_cancellations          32578 non-null  float64
#  14  no_of_previous_bookings_not_canceled  18026 non-null  float64
#  15  avg_price_per_room                    9058 non-null   float64
#  16  no_of_special_requests                25197 non-null  float64
#  17  booking_status                        32295 non-null  float64
# dtypes: float64(15), object(3)
# memory usage: 4.7+ MB

# %%
print(f'Number of rows:   {data.shape[0]:,}'.replace(',', ' '))
print(f'Number of unique indexes:   {data.index.nunique():,}'.replace(',', ' '))
print(f'Number of columns:   {data.shape[1]:,}'.replace(',', ' '))
# Out:
# Number of rows:   32 647
# Number of unique indexes:   32 647
# Number of columns:   18

# %%
#renaming the response variable, giving it a "working" tag

data.rename(columns = {'booking_status':'TARGET'}, inplace = True)
data.head()
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0

# %%
#assigning some variables for columns in dataset, which we will be using a lot (working with them is then easier)
col_target = "TARGET"
col_month = "arrival_month"

# %%
# define list of predictors
cols_pred = list(data.columns[0:-1])

# define list of numerical predictors
cols_pred_num = [col for col in cols_pred if data[col].dtype != 'O']
# define list of categorical predictors
cols_pred_cat = [col for col in cols_pred if data[col].dtype == 'O']

print('Numerical predictors:')
print('---------------------')
print(data[cols_pred_num].dtypes)
print()
print('Categorical predictors:')
print('-----------------------')
print(data[cols_pred_cat].dtypes)
# Out:
# Numerical predictors:
# ---------------------
# no_of_adults                            float64
# no_of_children                          float64
# no_of_weekend_nights                    float64
# no_of_week_nights                       float64
# required_car_parking_space              float64
# lead_time                               float64
# arrival_year                            float64
# arrival_month                           float64
# arrival_date                            float64
# repeated_guest                          float64
# no_of_previous_cancellations            float64
# no_of_previous_bookings_not_canceled    float64
# avg_price_per_room                      float64
# no_of_special_requests                  float64
# dtype: object
#
# Categorical predictors:
# -----------------------
# type_of_meal_plan      object
# room_type_reserved     object
# market_segment_type    object
# dtype: object

# %%
#Ověření, že nám to funguje
len(cols_pred),cols_pred
# Out:
# (17,
#  ['no_of_adults',
#   'no_of_children',
#   'no_of_weekend_nights',
#   'no_of_week_nights',
#   'type_of_meal_plan',
#   'required_car_parking_space',
#   'room_type_reserved',
#   'lead_time',
#   'arrival_year',
#   'arrival_month',
#   'arrival_date',
#   'market_segment_type',
#   'repeated_guest',
#   'no_of_previous_cancellations',
#   'no_of_previous_bookings_not_canceled',
#   'avg_price_per_room',
#   'no_of_special_requests'])

# %%
#Zjištění, kolik NA value v našem Targetu
data.TARGET.value_counts(dropna=False)
# Out:
# TARGET
# 0.0    21774
# 1.0    10521
# NaN      352
# Name: count, dtype: int64

# %%
#Dropping NAs from target variable
data = data.dropna(subset=["TARGET"])

# %%
#Dropping NAs from predictors, that have over 98% values missing (as then they cannot reasonably contribute to our final model)
data.drop(data.loc[:,list((100*(data.isnull().sum()/len(data.index))>98))].columns)
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN10204             NaN             NaN                   NaN
# INN20020             NaN             NaN                   NaN
# INN16435             1.0             NaN                   NaN
# INN07143             3.0             NaN                   NaN
# INN20511             1.0             0.0                   1.0
# ...                  ...             ...                   ...
# INN16851             2.0             NaN                   NaN
# INN06266             1.0             NaN                   NaN
# INN11285             2.0             NaN                   NaN
# INN00861             2.0             NaN                   NaN
# INN15796             2.0             NaN                   NaN
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN10204                  2.0       Meal Plan 2                         NaN
# INN20020                  2.0       Meal Plan 1                         NaN
# INN16435                  2.0               NaN                         0.0
# INN07143                  3.0               NaN                         NaN
# INN20511                  1.0       Meal Plan 1                         0.0
# ...                       ...               ...                         ...
# INN16851                  NaN       Meal Plan 1                         NaN
# INN06266                  2.0       Meal Plan 2                         0.0
# INN11285                  2.0               NaN                         NaN
# INN00861                  3.0       Meal Plan 1                         0.0
# INN15796                  2.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN10204          Room_Type 6        NaN        2018.0            9.0
# INN20020                  NaN        NaN           NaN           12.0
# INN16435          Room_Type 1        NaN        2018.0           11.0
# INN07143                  NaN      100.0        2018.0            5.0
# INN20511                  NaN        NaN        2018.0           11.0
# ...                       ...        ...           ...            ...
# INN16851                  NaN       43.0        2017.0           12.0
# INN06266          Room_Type 1      102.0        2017.0           10.0
# INN11285                  NaN        NaN        2018.0            5.0
# INN00861                  NaN        NaN        2018.0            6.0
# INN15796                  NaN       14.0        2018.0            9.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN10204             NaN              Online             0.0
# INN20020             NaN              Online             0.0
# INN16435             NaN                 NaN             0.0
# INN07143             NaN              Online             0.0
# INN20511             NaN                 NaN             0.0
# ...                  ...                 ...             ...
# INN16851            26.0             Offline             NaN
# INN06266             NaN              Online             NaN
# INN11285             NaN           Corporate             0.0
# INN00861             NaN              Online             NaN
# INN15796            15.0              Online             NaN
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN10204                             0.0
# INN20020                             0.0
# INN16435                             0.0
# INN07143                             0.0
# INN20511                             0.0
# ...                                  ...
# INN16851                             0.0
# INN06266                             0.0
# INN11285                             0.0
# INN00861                             0.0
# INN15796                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN10204                                     NaN                 NaN
# INN20020                                     0.0                 NaN
# INN16435                                     NaN                 NaN
# INN07143                                     NaN                 NaN
# INN20511                                     0.0               150.0
# ...                                          ...                 ...
# INN16851                                     0.0                 NaN
# INN06266                                     NaN                80.0
# INN11285                                     0.0                 NaN
# INN00861                                     NaN                 NaN
# INN15796                                     NaN                 NaN
#
#             no_of_special_requests  TARGET
# Booking_ID
# INN10204                       1.0     0.0
# INN20020                       NaN     0.0
# INN16435                       1.0     0.0
# INN07143                       2.0     0.0
# INN20511                       NaN     1.0
# ...                            ...     ...
# INN16851                       2.0     0.0
# INN06266                       NaN     1.0
# INN11285                       1.0     0.0
# INN00861                       0.0     1.0
# INN15796                       NaN     0.0
#
# [32295 rows x 18 columns]

# %% [markdown]
# # Rozdělení na test valid a data sample

# %%
data['sample'] = 'default'

# use train_test_split to split the intime into train and rest
data_train, data_rest = train_test_split(data, test_size=0.4, random_state = 12)
data.loc[data_train.index, 'sample'] = 'train'
# use train_test_split to split the rest into valid and test
data_valid, data_test = train_test_split(data_rest, test_size=0.5, random_state = 12)
data.loc[data_valid.index, 'sample'] = 'valid'
data.loc[data_test.index, 'sample'] = 'test'

# %% [markdown]
# ### Plotting the cancellations per month

# %%
def default_rate_in_time_per_sample(dt, col_target, col_month, col_sample):
    # group by over month and sample
    dt_grp = dt.groupby([col_month, col_sample]).agg(
        def_rt = (col_target, 'mean')
    ).reset_index()
    
    # pivot sample values to columns
    dt_grp_pivot = dt_grp.pivot(index = col_month, columns = col_sample, values = 'def_rt')

    # plot default rate in time
    lines = plt.plot(range(len(dt_grp_pivot)), dt_grp_pivot, marker = 'o')
    plt.xticks(range(len(dt_grp_pivot)), dt_grp_pivot.index, rotation = 90)
    # set legend
    plt.legend(iter(lines), tuple(dt_grp_pivot.columns), loc='best', bbox_to_anchor=(1.05, 1))
    
    plt.ylim([0, 1])
    plt.ylabel('default rate', loc='top')
    plt.xlabel('month', loc='right')
    
    ax = plt.gca()
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_color('gray')
    ax.spines['bottom'].set_color('gray')
    ax.tick_params(axis='y', colors='gray')
    ax.tick_params(axis='x', colors='gray') 
    
    plt.show()

# %%
default_rate_in_time_per_sample(data, col_target, col_month, 'sample')
#We can see the train, test and valid samples are roughly the same in each month, so we can consider this to be a good split

# %%
#we will again assign some variables for the subsets we will use a lot, working with them is then easier
train_mask = (data['sample'] == 'train')
valid_mask = (data['sample'] == 'valid') 
test_mask = (data['sample'] == 'test')

# %%
# find columns with infinity values
cols_with_inf = []
for col in cols_pred_num:
    if np.any(np.isinf(data[col])):
        cols_with_inf.append(col)
        print(f'Column {col} includes infinity values.')

# find columns with negative infinity values
cols_with_neginf = []
for col in cols_pred_num:
    if np.any(np.isneginf(data[col])):
        cols_with_neginf.append(col)
        print(f'Column {col} includes negative infinity values.')

# %%
# replace infinity values
for col in cols_with_inf:
    data[col] = data[col].replace(np.inf, 9999999)

# %% [markdown]
# ## Mean target encoding of categorical variables

# %%
def mean_target_encoding(dt, predictor, target, alpha = 0.01):
    total_cnt = len(dt)
    total_dr = np.mean(dt[target])
    dt_grp = dt.groupby(predictor).agg(
        categ_dr = (target, 'mean'),
        categ_cnt = (target, len)
    )
    
    dt_grp['categ_freq'] = dt_grp['categ_cnt'] / total_cnt
    dt_grp['categ_encoding'] = (dt_grp['categ_freq'] * dt_grp['categ_dr'] + alpha * total_dr) / (dt_grp['categ_freq'] + alpha)
    
    return dt_grp[['categ_encoding']].to_dict()['categ_encoding']

# %%
total_dr = np.mean(data[train_mask][col_target])
MTEdummies={}

# encode categorical predictors for training dataset
for pred in tqdm(cols_pred_cat):
    if len(data[pred].unique()) < 0:
        dummies = pd.get_dummies(
            data[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if data[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in data.columns:
                del data[d]
                
        data = data.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = mean_target_encoding(
            dt=data[train_mask], 
            predictor=pred, 
            target=col_target
        )
        MTEdummies[pred] = new_vals
        
        additional_values = set(data[data[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_dr

        data['MTE_' + pred] = data[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_children',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'arrival_date',
#  'repeated_guest',
#  'no_of_previous_cancellations',
#  'no_of_previous_bookings_not_canceled',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type']

# %%
# encode categorical predictors for the predictions dataset
for pred in tqdm(cols_pred_cat):
    if len(test[pred].unique()) < 0:
        dummies = pd.get_dummies(
            test[pred], 
            prefix = pred,
            prefix_sep = '_',
            dummy_na = True if test[pred].isnull().sum() > 0 else False,
            drop_first = False
        )
        
        for d in dummies.columns:
            if d in test.columns:
                del test[d]
                
        test = test.join(dummies)
        
        for col in dummies.columns:
            if col not in cols_pred:
                cols_pred.append(col)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
    else:
        new_vals = MTEdummies[pred]

        additional_values = set(test[test[pred].notnull()][pred].unique()) - set(new_vals.keys())
        for p in additional_values:
            new_vals[p] = total_dr

        test['MTE_' + pred] = test[pred].map(new_vals)
        
        if 'MTE_' + pred not in cols_pred:
            cols_pred.append('MTE_' + pred)
        
        if pred in cols_pred:
            cols_pred.remove(pred)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # First model (this is not the final model, however, it has to be run in order for some later stuff to work!)

# %%
# set best parameters to be used in XGBoost
params = {    
    'max_depth': 4,
    
    'objective': 'binary:logistic',
    'eval_metric': ['auc'],
}

evals_result = {}
booster = xgb.train(
    params = params,
    dtrain = xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]),
    num_boost_round = 1000,
    evals = (
        (xgb.DMatrix(data[train_mask][cols_pred], data[train_mask][col_target]), 'train'),
        (xgb.DMatrix(data[valid_mask][cols_pred], data[valid_mask][col_target]), 'valid'),        
    ),
    evals_result = evals_result,
    early_stopping_rounds = 10
)
# Out:
# [0]	train-auc:0.70896	valid-auc:0.70086
# [1]	train-auc:0.74298	valid-auc:0.73440
# [2]	train-auc:0.75825	valid-auc:0.75413
# [3]	train-auc:0.76795	valid-auc:0.76318
# [4]	train-auc:0.77516	valid-auc:0.76882
# [5]	train-auc:0.78349	valid-auc:0.77789
# [6]	train-auc:0.78574	valid-auc:0.77990
# [7]	train-auc:0.78985	valid-auc:0.78316
# [8]	train-auc:0.79269	valid-auc:0.78575
# [9]	train-auc:0.79447	valid-auc:0.78778
# [10]	train-auc:0.79750	valid-auc:0.79025
# [11]	train-auc:0.79762	valid-auc:0.79081
# [12]	train-auc:0.79944	valid-auc:0.79232
# [13]	train-auc:0.80143	valid-auc:0.79384
# [14]	train-auc:0.80237	valid-auc:0.79477
# [15]	train-auc:0.80329	valid-auc:0.79550
# [16]	train-auc:0.80405	valid-auc:0.79581
# [17]	train-auc:0.80519	valid-auc:0.79606
# [18]	train-auc:0.80538	valid-auc:0.79631
# [19]	train-auc:0.80579	valid-auc:0.79661
# [20]	train-auc:0.80629	valid-auc:0.79719
# [21]	train-auc:0.80796	valid-auc:0.79909
# [22]	train-auc:0.80823	valid-auc:0.79927
# [23]	train-auc:0.80872	valid-auc:0.79955
# [24]	train-auc:0.80898	valid-auc:0.79939
# [25]	train-auc:0.81073	valid-auc:0.80059
# [26]	train-auc:0.81230	valid-auc:0.80153
# [27]	train-auc:0.81230	valid-auc:0.80162
# [28]	train-auc:0.81391	valid-auc:0.80283
# [29]	train-auc:0.81527	valid-auc:0.80312
# [30]	train-auc:0.81543	valid-auc:0.80325
# [31]	train-auc:0.81580	valid-auc:0.80366
# [32]	train-auc:0.81623	valid-auc:0.80393
# [33]	train-auc:0.81677	valid-auc:0.80428
# [34]	train-auc:0.81755	valid-auc:0.80433
# [35]	train-auc:0.81775	valid-auc:0.80479
# [36]	train-auc:0.81820	valid-auc:0.80533
# [37]	train-auc:0.81891	valid-auc:0.80514
# [38]	train-auc:0.81936	valid-auc:0.80532
# [39]	train-auc:0.82055	valid-auc:0.80597
# [40]	train-auc:0.82122	valid-auc:0.80629
# [41]	train-auc:0.82126	valid-auc:0.80635
# [42]	train-auc:0.82181	valid-auc:0.80631
# [43]	train-auc:0.82199	valid-auc:0.80635
# [44]	train-auc:0.82294	valid-auc:0.80736
# [45]	train-auc:0.82389	valid-auc:0.80773
# [46]	train-auc:0.82496	valid-auc:0.80735
# [47]	train-auc:0.82549	valid-auc:0.80754
# [48]	train-auc:0.82557	valid-auc:0.80762
# [49]	train-auc:0.82583	valid-auc:0.80774
# [50]	train-auc:0.82641	valid-auc:0.80813
# [51]	train-auc:0.82660	valid-auc:0.80827
# [52]	train-auc:0.82675	valid-auc:0.80827
# [53]	train-auc:0.82684	valid-auc:0.80822
# [54]	train-auc:0.82707	valid-auc:0.80825
# [55]	train-auc:0.82729	valid-auc:0.80859
# [56]	train-auc:0.82752	valid-auc:0.80874
# [57]	train-auc:0.82860	valid-auc:0.80863
# [58]	train-auc:0.82884	valid-auc:0.80863
# [59]	train-auc:0.82918	valid-auc:0.80863
# [60]	train-auc:0.82947	valid-auc:0.80885
# [61]	train-auc:0.82998	valid-auc:0.80909
# [62]	train-auc:0.83067	valid-auc:0.80894
# [63]	train-auc:0.83061	valid-auc:0.80893
# [64]	train-auc:0.83140	valid-auc:0.80955
# [65]	train-auc:0.83209	valid-auc:0.80967
# [66]	train-auc:0.83226	valid-auc:0.80973
# [67]	train-auc:0.83241	valid-auc:0.80980
# [68]	train-auc:0.83289	valid-auc:0.80946
# [69]	train-auc:0.83369	valid-auc:0.80940
# [70]	train-auc:0.83414	valid-auc:0.80946
# [71]	train-auc:0.83436	valid-auc:0.80940
# [72]	train-auc:0.83446	valid-auc:0.80943
# [73]	train-auc:0.83457	valid-auc:0.80945
# [74]	train-auc:0.83479	valid-auc:0.80944
# [75]	train-auc:0.83514	valid-auc:0.80945
# [76]	train-auc:0.83543	valid-auc:0.80952

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster.best_score
best_iteration = booster.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
importance_type = 'total_gain'

predictor_strength = sorted([(k, v) for k,v in booster.get_score(importance_type = importance_type).items()], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = len(cols_pred)
plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:20])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:20])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# # Final model

# %% [markdown]
# ### Tento model jsme využili pro naši finální predikce, již má odstraněné nepodstatné prediktory, které při odstranění příliš nesnížili příliš AUC

# %%
#Removing least important predictor)
cols_pred.remove("no_of_children")
cols_pred.remove("arrival_date")
cols_pred.remove("no_of_previous_cancellations")
cols_pred.remove("repeated_guest")
#cols_pred.remove("required_car_parking_space")
#cols_pred.remove("MTE_room_type_reserved")
cols_pred.remove("no_of_previous_bookings_not_canceled")
#cols_pred.remove("no_of_weekend_nights")

# %%
#Nevsimat si
#skusali sme nahradit chybajuce NAs pri lead_time prediktore ich priemerom (takym specialnym, bol pocitany iba z hodnot medzi 0-180 ...casy do pol roka
# ... lebo si myslime, ze kazde pozorovanie nad 180 ... cize pol roka dopredu... je outlier a dost by tento priemer kazil. Nakoniec sme to aj tak nepouzili)
#mean_lead_time=data[train_mask].loc[data[train_mask]['lead_time'].between(0,180), 'lead_time'].mean(skipna=True)
#mean_lead_time

# %%
#Zobrazení, zda jsme odstranili všechny prediktory, které jsme chtěli odstranit
cols_pred
# Out:
# ['no_of_adults',
#  'no_of_weekend_nights',
#  'no_of_week_nights',
#  'required_car_parking_space',
#  'lead_time',
#  'arrival_year',
#  'arrival_month',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'MTE_type_of_meal_plan',
#  'MTE_room_type_reserved',
#  'MTE_market_segment_type']

# %%
#data.avg_price_per_room.value_counts(dropna=False)

# %%
#takisto pozostatok z pokusov, snazili sme sa nahradit chybajuce hodnoty avg_room_price ich priemerom, vysledny model ale nevysiel bohviejako dobre

#mean_avg_price_per_room=data.avg_price_per_room.mean(skipna=True)
#mean_avg_price_per_room
#data['avg_price_per_room'] = data.avg_price_per_room.fillna(value=mean_avg_price_per_room)

# %%
#rep=data[train_mask].copy().avg_price_per_room.fillna(value=mean_avg_price_per_room)
#rep=rep.tolist()
#help=data[train_mask].copy()
#help['avg_price_per_room'] = rep
#data[train_mask] = help

# %%
#data[train_mask].avg_price_per_room.value_counts(dropna=False)

# %%
booster_sklearn = xgb.XGBClassifier(
    booster='gbtree',
    objective='binary:logistic',
    random_state=12,
    max_depth=6,
    eval_metric=['auc'],
    gamma=0.3,
    verbosity=1,
    use_label_encoder=False,
    early_stopping_rounds=10,
    eta=0.2
)

booster_sklearn.fit(
    data[train_mask][cols_pred].values, 
    data[train_mask][col_target].astype(int).values,
    eval_set=[
        (data[train_mask][cols_pred].values, data[train_mask][col_target].values),
        (data[test_mask][cols_pred].values, data[test_mask][col_target].values),
        (data[valid_mask][cols_pred].values, data[valid_mask][col_target].values),
    ],
    verbose=True,
)
# Out:
# [0]	validation_0-auc:0.75533	validation_1-auc:0.75975	validation_2-auc:0.74694
# [1]	validation_0-auc:0.77062	validation_1-auc:0.77000	validation_2-auc:0.76177
# [2]	validation_0-auc:0.78147	validation_1-auc:0.77831	validation_2-auc:0.77163
# [3]	validation_0-auc:0.78570	validation_1-auc:0.78302	validation_2-auc:0.77522
# [4]	validation_0-auc:0.78890	validation_1-auc:0.78679	validation_2-auc:0.77791
# [5]	validation_0-auc:0.79307	validation_1-auc:0.78992	validation_2-auc:0.78295
# [6]	validation_0-auc:0.79611	validation_1-auc:0.79204	validation_2-auc:0.78512
# [7]	validation_0-auc:0.80179	validation_1-auc:0.79634	validation_2-auc:0.78953
# [8]	validation_0-auc:0.80360	validation_1-auc:0.79754	validation_2-auc:0.79122
# [9]	validation_0-auc:0.80820	validation_1-auc:0.79988	validation_2-auc:0.79486
# [10]	validation_0-auc:0.80957	validation_1-auc:0.80080	validation_2-auc:0.79592
# [11]	validation_0-auc:0.81061	validation_1-auc:0.80165	validation_2-auc:0.79739
# [12]	validation_0-auc:0.81451	validation_1-auc:0.80374	validation_2-auc:0.79978
# [13]	validation_0-auc:0.81517	validation_1-auc:0.80432	validation_2-auc:0.80101
# [14]	validation_0-auc:0.81626	validation_1-auc:0.80517	validation_2-auc:0.80215
# [15]	validation_0-auc:0.81749	validation_1-auc:0.80579	validation_2-auc:0.80300
# [16]	validation_0-auc:0.82015	validation_1-auc:0.80620	validation_2-auc:0.80380
# [17]	validation_0-auc:0.82036	validation_1-auc:0.80659	validation_2-auc:0.80420
# [18]	validation_0-auc:0.82127	validation_1-auc:0.80750	validation_2-auc:0.80484
# [19]	validation_0-auc:0.82190	validation_1-auc:0.80825	validation_2-auc:0.80536
# [20]	validation_0-auc:0.82281	validation_1-auc:0.80841	validation_2-auc:0.80570
# [21]	validation_0-auc:0.82337	validation_1-auc:0.80856	validation_2-auc:0.80575
# [22]	validation_0-auc:0.82444	validation_1-auc:0.80905	validation_2-auc:0.80654
# [23]	validation_0-auc:0.82644	validation_1-auc:0.80972	validation_2-auc:0.80705
# [24]	validation_0-auc:0.82652	validation_1-auc:0.80979	validation_2-auc:0.80715
# [25]	validation_0-auc:0.82810	validation_1-auc:0.81074	validation_2-auc:0.80798
# [26]	validation_0-auc:0.82908	validation_1-auc:0.81100	validation_2-auc:0.80825
# [27]	validation_0-auc:0.83117	validation_1-auc:0.81173	validation_2-auc:0.80935
# [28]	validation_0-auc:0.83143	validation_1-auc:0.81168	validation_2-auc:0.80967
# [29]	validation_0-auc:0.83291	validation_1-auc:0.81227	validation_2-auc:0.81051
# [30]	validation_0-auc:0.83303	validation_1-auc:0.81239	validation_2-auc:0.81061
# [31]	validation_0-auc:0.83345	validation_1-auc:0.81273	validation_2-auc:0.81070
# [32]	validation_0-auc:0.83380	validation_1-auc:0.81277	validation_2-auc:0.81107
# [33]	validation_0-auc:0.83518	validation_1-auc:0.81255	validation_2-auc:0.81133
# [34]	validation_0-auc:0.83561	validation_1-auc:0.81256	validation_2-auc:0.81144
# [35]	validation_0-auc:0.83740	validation_1-auc:0.81293	validation_2-auc:0.81152
# [36]	validation_0-auc:0.83738	validation_1-auc:0.81293	validation_2-auc:0.81152
# [37]	validation_0-auc:0.83741	validation_1-auc:0.81291	validation_2-auc:0.81155
# [38]	validation_0-auc:0.83816	validation_1-auc:0.81311	validation_2-auc:0.81146
# [39]	validation_0-auc:0.83981	validation_1-auc:0.81351	validation_2-auc:0.81195
# [40]	validation_0-auc:0.84042	validation_1-auc:0.81392	validation_2-auc:0.81263
# [41]	validation_0-auc:0.84093	validation_1-auc:0.81403	validation_2-auc:0.81249
# [42]	validation_0-auc:0.84120	validation_1-auc:0.81383	validation_2-auc:0.81246
# [43]	validation_0-auc:0.84142	validation_1-auc:0.81385	validation_2-auc:0.81251
# [44]	validation_0-auc:0.84262	validation_1-auc:0.81353	validation_2-auc:0.81284
# [45]	validation_0-auc:0.84315	validation_1-auc:0.81344	validation_2-auc:0.81284
# [46]	validation_0-auc:0.84429	validation_1-auc:0.81395	validation_2-auc:0.81336
# [47]	validation_0-auc:0.84542	validation_1-auc:0.81444	validation_2-auc:0.81366
# [48]	validation_0-auc:0.84594	validation_1-auc:0.81446	validation_2-auc:0.81382
# [49]	validation_0-auc:0.84616	validation_1-auc:0.81428	validation_2-auc:0.81375
# [50]	validation_0-auc:0.84724	validation_1-auc:0.81460	validation_2-auc:0.81370
# [51]	validation_0-auc:0.84758	validation_1-auc:0.81478	validation_2-auc:0.81401
# [52]	validation_0-auc:0.84766	validation_1-auc:0.81482	validation_2-auc:0.81405
# [53]	validation_0-auc:0.84784	validation_1-auc:0.81484	validation_2-auc:0.81433
# [54]	validation_0-auc:0.84941	validation_1-auc:0.81499	validation_2-auc:0.81485
# [55]	validation_0-auc:0.84993	validation_1-auc:0.81468	validation_2-auc:0.81487
# [56]	validation_0-auc:0.85041	validation_1-auc:0.81468	validation_2-auc:0.81465
# [57]	validation_0-auc:0.85132	validation_1-auc:0.81463	validation_2-auc:0.81455
# [58]	validation_0-auc:0.85145	validation_1-auc:0.81463	validation_2-auc:0.81465
# [59]	validation_0-auc:0.85179	validation_1-auc:0.81462	validation_2-auc:0.81468
# [60]	validation_0-auc:0.85199	validation_1-auc:0.81461	validation_2-auc:0.81479
# [61]	validation_0-auc:0.85220	validation_1-auc:0.81463	validation_2-auc:0.81479
# [62]	validation_0-auc:0.85224	validation_1-auc:0.81461	validation_2-auc:0.81486
# [63]	validation_0-auc:0.85306	validation_1-auc:0.81505	validation_2-auc:0.81471
# [64]	validation_0-auc:0.85316	validation_1-auc:0.81500	validation_2-auc:0.81468
# [65]	validation_0-auc:0.85403	validation_1-auc:0.81526	validation_2-auc:0.81510
# [66]	validation_0-auc:0.85479	validation_1-auc:0.81516	validation_2-auc:0.81517
# [67]	validation_0-auc:0.85495	validation_1-auc:0.81516	validation_2-auc:0.81528
# [68]	validation_0-auc:0.85535	validation_1-auc:0.81519	validation_2-auc:0.81556
# [69]	validation_0-auc:0.85599	validation_1-auc:0.81505	validation_2-auc:0.81563
# [70]	validation_0-auc:0.85640	validation_1-auc:0.81519	validation_2-auc:0.81533
# [71]	validation_0-auc:0.85660	validation_1-auc:0.81509	validation_2-auc:0.81538
# [72]	validation_0-auc:0.85670	validation_1-auc:0.81504	validation_2-auc:0.81539
# [73]	validation_0-auc:0.85808	validation_1-auc:0.81515	validation_2-auc:0.81550
# [74]	validation_0-auc:0.85901	validation_1-auc:0.81518	validation_2-auc:0.81553
# [75]	validation_0-auc:0.85937	validation_1-auc:0.81512	validation_2-auc:0.81575
# [76]	validation_0-auc:0.86048	validation_1-auc:0.81496	validation_2-auc:0.81575
# [77]	validation_0-auc:0.86068	validation_1-auc:0.81499	validation_2-auc:0.81581
# [78]	validation_0-auc:0.86197	validation_1-auc:0.81521	validation_2-auc:0.81589
# [79]	validation_0-auc:0.86269	validation_1-auc:0.81527	validation_2-auc:0.81581
# [80]	validation_0-auc:0.86285	validation_1-auc:0.81529	validation_2-auc:0.81551
# [81]	validation_0-auc:0.86354	validation_1-auc:0.81555	validation_2-auc:0.81595
# [82]	validation_0-auc:0.86437	validation_1-auc:0.81555	validation_2-auc:0.81617
# [83]	validation_0-auc:0.86450	validation_1-auc:0.81559	validation_2-auc:0.81607
# [84]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [85]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [86]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [87]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [88]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [89]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [90]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [91]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [92]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [93]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [94]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# [95]	validation_0-auc:0.86526	validation_1-auc:0.81564	validation_2-auc:0.81622
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eta=0.2, eval_metric=['auc'],
#               feature_types=None, gamma=0.3, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
metric = 'auc'

fig = plt.figure(figsize=(6,5))
ax = plt.subplot(1,1,1)
total_iteration_count = len(evals_result[list(evals_result.keys())[0]][metric])
for sample, vals in evals_result.items():
    ax.plot(
        range(1, total_iteration_count + 1), 
        vals[metric],
        label=sample
    )

best_score = booster_sklearn.best_score
best_iteration = booster_sklearn.best_iteration+1

ax.plot([1, total_iteration_count], [best_score, best_score], color='black', ls='--', lw=1)
ax.scatter([best_iteration], [best_score], color = 'black')
ax.annotate(
    '{:d}; {:0.3f}'.format(best_iteration, best_score), 
    xy = (best_iteration, best_score), 
    xytext = (best_iteration,best_score+0.005),
)
ax.set_xlabel('iteration', color='gray')
ax.set_ylabel(metric, color='gray')
ax.legend(loc='best')
ax.set_title(f'Model training - {metric} curves')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

# %%
importance_type = 'total_gain'

orig_feature_names = cols_pred
booster_sklearn.get_booster().feature_names = orig_feature_names

predictor_strength = sorted([(k, v) for k,v in booster_sklearn.get_booster().get_score(importance_type = importance_type).items()], key = lambda x: x[1], reverse = True)
predictor_strength = pd.DataFrame(predictor_strength, columns = ['predictor', 'strength'])

fig = plt.figure(figsize=(6,5))

n_strongest = len(cols_pred)

plt.barh(range(n_strongest, 0, -1), predictor_strength['strength'].iloc[0:20])
plt.yticks(range(n_strongest, 0, -1), predictor_strength['predictor'].iloc[0:20])
plt.xlabel(importance_type)
plt.title('Predictor importance')

ax = plt.gca()
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_color('gray')
ax.spines['bottom'].set_color('gray')
ax.tick_params(axis='y', colors='gray')
ax.tick_params(axis='x', colors='gray')

plt.show()

# %% [markdown]
# ### Prediktory sme vyhadzovali podla ich dolezitosti na total gainu ale aj podla "selskeho rozumu"
# #### Napriklad room type hovori o type izby, aku si klient rezervoval. Ked si rezervoval nejaku luxusnu izbu, tak pravdepodobne tu rezervaciu len tak nezrusi. Este napriklad required car parking space hovori o tom, ci host pozaduje parkovanie. Ludia bez auta maju podla nasho nazoru mensiu pravdepodobnost sa dostavit nez ludia, ktori auto maju, takze ano, zalezi na tomto prediktore.

# %%
def marginal_dependence(data, predictor, bins, col_target):
    dt = data.copy()
    dt[predictor + 'bin'] = pd.qcut(dt.rank(method='first')[predictor], bins).copy() #pd.qcut(df.rank(method='first'), nbins)
    dt.groupby(predictor + 'bin', observed=False).agg(
        def_prob=(col_target, np.mean)
    ).plot(figsize=(9, 6))

# %%
#marginalna dependencia jedneho z prediktorov
marginal_dependence(data[train_mask], 'no_of_weekend_nights', 10, col_target)
# Out:
# C:\Users\matej\AppData\Local\Temp\ipykernel_57108\3003329733.py:4: FutureWarning: The provided callable <function mean at 0x0000024C1C8FBF40> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   dt.groupby(predictor + 'bin', observed=False).agg(

# %% [markdown]
# # Predikcie

# %%
# calculating predictions based on our model
test['predicted_pd'] = booster_sklearn.get_booster().predict(xgb.DMatrix(test[cols_pred]), iteration_range=(0,booster_sklearn.best_iteration))
test['predicted_score'] = np.log(test['predicted_pd'] / (1 - test['predicted_pd']))

# %%
def plot_score_calibration(dt, col_score, col_target, n_bins = 25):
    min_score = dt[col_score].min() - 0.1
    max_score = dt[col_score].max() + 0.1
    
    bins = [round(min_score + i * (max_score - min_score) / n_bins, 2) for i in range(n_bins+1)]
    dt = dt.assign(score_bin = pd.cut(dt[col_score], bins = bins, include_lowest = False))
    
    dt_grp = dt.groupby('score_bin', observed=False).agg(
        bad_cnt = (col_target, 'sum'),
        tot_cnt = (col_target, len),
        def_rt = (col_target, 'mean'),
        avg_score = (col_score, 'mean')
    )
    dt_grp['good_cnt'] = dt_grp['tot_cnt'] - dt_grp['bad_cnt']
    dt_grp['bad_cnt_norm'] = dt_grp['bad_cnt'] / dt_grp['tot_cnt']
    dt_grp['good_cnt_norm'] = dt_grp['good_cnt'] / dt_grp['tot_cnt']
    dt_grp['expected_pd'] = 1 / (1 + np.exp(-dt_grp['avg_score']))
    
    fig, axs = plt.subplots(1,2, figsize = (12,4))
    fig.suptitle(col_score)
    plt.subplots_adjust(wspace = 0.4)
    axs[0].bar(range(len(dt_grp)), dt_grp['bad_cnt'], color = 'salmon', label = 'bads')
    axs[0].bar(range(len(dt_grp)), dt_grp['good_cnt'], bottom = dt_grp['bad_cnt'], color = 'lightblue', label = 'goods')
    axs[0].set_ylabel('observations count')
    axs[0].set_xlabel('score')
    axs[0].set_xticks(range(len(dt_grp)))
    axs[0].set_xticklabels(dt_grp.index, rotation = 90)
    
    axs[0].spines['right'].set_color('gray')
    axs[0].spines['top'].set_visible(False)
    axs[0].spines['left'].set_color('gray')
    axs[0].spines['bottom'].set_color('gray')
    axs[0].tick_params(axis='y', colors='gray')
    axs[0].tick_params(axis='x', colors='gray')
    
    ax0l = axs[0].twinx()
    ax0l.plot(range(len(dt_grp)), dt_grp['def_rt'], marker = 'o', color = 'red')
    ax0l.plot(range(len(dt_grp)), dt_grp['expected_pd'], color = 'black', ls = '--')
    ax0l.set_ylabel('default rate', color = 'red')
    
    ax0l.spines['right'].set_color('gray')
    ax0l.spines['top'].set_visible(False)
    ax0l.spines['left'].set_color('gray')
    ax0l.spines['bottom'].set_color('gray')
    ax0l.tick_params(axis='y', colors='gray')
    ax0l.tick_params(axis='x', colors='gray')
    
    axs[1].bar(range(len(dt_grp)), dt_grp['bad_cnt_norm'], color = 'salmon', label = 'bads')
    axs[1].bar(range(len(dt_grp)), dt_grp['good_cnt_norm'], bottom = dt_grp['bad_cnt_norm'], color = 'lightblue', label = 'goods')
    axs[1].set_ylabel('frequency')
    axs[1].set_xlabel('score')
    axs[1].set_xticks(range(len(dt_grp)))
    axs[1].set_xticklabels(dt_grp.index, rotation = 90)
    
    axs[1].spines['right'].set_visible(False)
    axs[1].spines['top'].set_visible(False)
    axs[1].spines['left'].set_color('gray')
    axs[1].spines['bottom'].set_color('gray')
    axs[1].tick_params(axis='y', colors='gray')
    axs[1].tick_params(axis='x', colors='gray')

# %%
#Predikovaná skóre
plot_score_calibration(test, 'predicted_score', 'predicted_pd')

# %%
#Vyobrazenie našeho modelu ... jeho rozhodovací strom (je potrebne nainstalovat Graphviz)
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin' #treba nastavit svoj priecinok kde je nainstalovany graphviz...dolezity je potom bin

from xgboost import plot_tree
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,50

plot_tree(booster_sklearn, num_trees = 0)
plt.show()

rcParams['figure.figsize'] = 5,5

# %%
#predikovane pravdepodobnosti
test['predicted_pd']
# Out:
# Booking_ID
# INN04969    0.002157
# INN34541    0.237080
# INN36109    0.165434
# INN01554    0.752330
# INN24975    0.175933
#               ...
# INN29523    0.014103
# INN25061    0.368285
# INN08475    0.969322
# INN13558    0.302169
# INN00626    0.107037
# Name: predicted_pd, Length: 3593, dtype: float32

# %%
#vytvaranie formatu pre kaggle
test['booking_status']=test['predicted_pd']

# %%
#posledna kontrola
test
# Out:
#             no_of_adults  no_of_children  no_of_weekend_nights  \
# Booking_ID
# INN04969             2.0             NaN                   1.0
# INN34541             2.0             0.0                   NaN
# INN36109             2.0             NaN                   NaN
# INN01554             2.0             NaN                   0.0
# INN24975             2.0             NaN                   NaN
# ...                  ...             ...                   ...
# INN29523             1.0             NaN                   NaN
# INN25061             2.0             NaN                   1.0
# INN08475             2.0             NaN                   NaN
# INN13558             1.0             NaN                   NaN
# INN00626             2.0             NaN                   0.0
#
#             no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# Booking_ID
# INN04969                  0.0       Meal Plan 1                         NaN
# INN34541                  2.0       Meal Plan 1                         0.0
# INN36109                  2.0       Meal Plan 1                         0.0
# INN01554                  3.0               NaN                         0.0
# INN24975                  NaN               NaN                         0.0
# ...                       ...               ...                         ...
# INN29523                  2.0       Meal Plan 2                         0.0
# INN25061                  NaN      Not Selected                         0.0
# INN08475                  NaN               NaN                         NaN
# INN13558                  0.0       Meal Plan 1                         NaN
# INN00626                  4.0               NaN                         NaN
#
#            room_type_reserved  lead_time  arrival_year  arrival_month  \
# Booking_ID
# INN04969                  NaN        NaN        2017.0            8.0
# INN34541                  NaN        NaN        2018.0            2.0
# INN36109                  NaN        NaN        2018.0           12.0
# INN01554                  NaN        NaN        2018.0            6.0
# INN24975                  NaN        NaN        2018.0            9.0
# ...                       ...        ...           ...            ...
# INN29523          Room_Type 1       39.0        2017.0            8.0
# INN25061                  NaN        NaN        2018.0            6.0
# INN08475                  NaN      308.0        2018.0           11.0
# INN13558                  NaN        NaN        2018.0            7.0
# INN00626          Room_Type 4        NaN        2017.0           10.0
#
#             arrival_date market_segment_type  repeated_guest  \
# Booking_ID
# INN04969            23.0                 NaN             NaN
# INN34541             NaN             Offline             NaN
# INN36109             NaN                 NaN             NaN
# INN01554            21.0              Online             NaN
# INN24975             NaN                 NaN             NaN
# ...                  ...                 ...             ...
# INN29523             NaN             Offline             NaN
# INN25061             NaN              Online             0.0
# INN08475             NaN              Online             NaN
# INN13558            24.0                 NaN             NaN
# INN00626             NaN                 NaN             0.0
#
#             no_of_previous_cancellations  \
# Booking_ID
# INN04969                             0.0
# INN34541                             0.0
# INN36109                             0.0
# INN01554                             0.0
# INN24975                             0.0
# ...                                  ...
# INN29523                             0.0
# INN25061                             0.0
# INN08475                             0.0
# INN13558                             3.0
# INN00626                             0.0
#
#             no_of_previous_bookings_not_canceled  avg_price_per_room  \
# Booking_ID
# INN04969                                     NaN                 NaN
# INN34541                                     0.0                 NaN
# INN36109                                     NaN                 NaN
# INN01554                                     0.0                 NaN
# INN24975                                     NaN                 NaN
# ...                                          ...                 ...
# INN29523                                     NaN               87.00
# INN25061                                     NaN                 NaN
# INN08475                                     0.0               78.30
# INN13558                                    39.0                 NaN
# INN00626                                     0.0               87.54
#
#             no_of_special_requests  MTE_type_of_meal_plan  \
# Booking_ID
# INN04969                       3.0               0.314747
# INN34541                       NaN               0.314747
# INN36109                       NaN               0.314747
# INN01554                       0.0                    NaN
# INN24975                       2.0                    NaN
# ...                            ...                    ...
# INN29523                       NaN               0.429450
# INN25061                       NaN               0.328849
# INN08475                       NaN                    NaN
# INN13558                       0.0               0.314747
# INN00626                       NaN                    NaN
#
#             MTE_room_type_reserved  MTE_market_segment_type  predicted_pd  \
# Booking_ID
# INN04969                       NaN                      NaN      0.002157
# INN34541                       NaN                 0.304221      0.237080
# INN36109                       NaN                      NaN      0.165434
# INN01554                       NaN                 0.363562      0.752330
# INN24975                       NaN                      NaN      0.175933
# ...                            ...                      ...           ...
# INN29523                  0.323375                 0.304221      0.014103
# INN25061                       NaN                 0.363562      0.368285
# INN08475                       NaN                 0.363562      0.969322
# INN13558                       NaN                      NaN      0.302169
# INN00626                  0.346501                      NaN      0.107037
#
#             predicted_score  booking_status
# Booking_ID
# INN04969          -6.136821        0.002157
# INN34541          -1.168755        0.237080
# INN36109          -1.618339        0.165434
# INN01554           1.111077        0.752330
# INN24975          -1.544148        0.175933
# ...                     ...             ...
# INN29523          -4.247181        0.014103
# INN25061          -0.539582        0.368285
# INN08475           3.453056        0.969322
# INN13558          -0.836992        0.302169
# INN00626          -2.121366        0.107037
#
# [3593 rows x 23 columns]

# %%
#prekonvertovanie do CSV
test['booking_status'].to_csv('eval.csv')
